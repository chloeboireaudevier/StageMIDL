# %%
#Imports
import pandas as pd # type: ignore
from pathlib import Path
import os
from openai import OpenAI #type: ignore
import numpy as np #type: ignore
from tqdm import tqdm #type: ignore
import json
import demjson3 # type: ignore
from IPython.display import clear_output # type: ignore
from dotenv import load_dotenv #type: ignore
from mistralai import Mistral #type: ignore

# %% [markdown]
# # Nombre de mots, nombre de caractères et source du message

# %%
all_messages = pd.read_csv('all_messages.csv')
all_messages.head(2)
# Out:
#    messageID      user       role                   message  groupID  \
# 0          0  186202.0  Navigator               Tu es qui ,        0
# 1          1  186202.0  Navigator  On se met 5 partout ok ?        0
#
#                                  fileID        date      time  seanceID
# 0  023a3090-7b0a-48c4-93f0-c200d9afce41  2024-10-09  04:38:10         1
# 1  023a3090-7b0a-48c4-93f0-c200d9afce41  2024-10-09  04:38:23         1

# %%
attributed = all_messages.copy()

# %%
attributed['taille'] = [len(str(m)) for m in attributed['message']]
attributed['nombre mots'] = [len(list(filter(None,str(m).split(' ')))) for m in attributed['message']] #Code complexe pour éviter le comptage des chaines vides dues au split (ex message 4)
attributed['source'] = attributed['role']
attributed.head(5)
# Out:
#    messageID      user       role                   message  groupID  \
# 0          0  186202.0  Navigator               Tu es qui ,        0
# 1          1  186202.0  Navigator  On se met 5 partout ok ?        0
# 2          2  183897.0     Driver                       Opé        1
# 3          3  183897.0     Driver                  Opé lmkt        1
# 4          4  193392.0  Navigator         A PAR SA LE COUZ         1
#
#                                  fileID        date      time  seanceID  \
# 0  023a3090-7b0a-48c4-93f0-c200d9afce41  2024-10-09  04:38:10         1
# 1  023a3090-7b0a-48c4-93f0-c200d9afce41  2024-10-09  04:38:23         1
# 2  0435458c-dc49-4094-b970-1db125fc235c  2024-10-09  04:21:22         1
# 3  0435458c-dc49-4094-b970-1db125fc235c  2024-10-09  04:21:39         1
# 4  0435458c-dc49-4094-b970-1db125fc235c  2024-10-09  04:21:46         1
#
#    taille  nombre mots     source
# 0      11            4  Navigator
# 1      24            7  Navigator
# 2       3            1     Driver
# 3       8            2     Driver
# 4      17            5  Navigator

# %% [markdown]
# # Classification automatique : données et fonctions générales

# %%
# Read the .csv file with the messages
df = pd.read_csv('all_messages.csv')

df.head(3)
# Out:
#    messageID      user       role                   message  groupID  \
# 0          0  186202.0  Navigator               Tu es qui ,        0
# 1          1  186202.0  Navigator  On se met 5 partout ok ?        0
# 2          2  183897.0     Driver                       Opé        1
#
#                                  fileID        date      time  seanceID
# 0  023a3090-7b0a-48c4-93f0-c200d9afce41  2024-10-09  04:38:10         1
# 1  023a3090-7b0a-48c4-93f0-c200d9afce41  2024-10-09  04:38:23         1
# 2  0435458c-dc49-4094-b970-1db125fc235c  2024-10-09  04:21:22         1

# %% [markdown]
# ### Structuration des données

# %%
# Ensure that the message num is an integer for sorting
df['messageID'] = df['messageID'].astype(int) 
df['groupID'] = df['groupID'].astype(int) 
df['seanceID'] = df['seanceID'].astype(int)
df['fileID'] = df['fileID'].astype('string') 

# Group the dataframe by conversation
grouped = df.groupby(['seanceID','groupID'])

map_messageId_fileId = {}

# We'll save the conversations as an array of dictionaries were every conversation is an entry
conversations_dict = []
# For every conversation in the dataframe
for activity_id, group in grouped:
    # Convert the utterances into a list of dictionaries, then sort entries by message num
    conversation_text = group.sort_values('messageID').apply(
        lambda row: {"messageID": row['messageID'], "role": row['role'], "message": row['message']},
        axis=1
    ).tolist()
    
    for idx, row in group.iterrows():
        map_messageId_fileId[row['messageID']] = row['fileID']

    # Create a conversation
    conversation = {
        "seance_ID": activity_id[0],
        "groupe_ID": activity_id[1],
        "conversation": conversation_text
    }
    # Append the conversations as a dictionary
    conversations_dict.append(conversation)

# This is not a JSON, it will be important later
conversations_dict[0]
# Out:
# {'seance_ID': 1,
#  'groupe_ID': 0,
#  'conversation': [{'messageID': 0,
#    'role': 'Navigator',
#    'message': 'Tu es qui ,'},
#   {'messageID': 1,
#    'role': 'Navigator',
#    'message': 'On se met 5 partout ok ?'}]}

# %%
#conversations_dict[4]
map_messageId_fileId[4]
# Out:
# '0435458c-dc49-4094-b970-1db125fc235c'

# %% [markdown]
# ### Lecture des prompts

# %%
def read_prompts(folder: str):
    '''
    Reads system, user, and agent prompts from text files in a specified folder.

    This function constructs file paths for `prompt_system.txt`, `prompt_user.txt`, and
    `prompt_agent.txt` within the given folder, reads their contents, and returns them
    as a tuple of strings.

    Args:
        folder (str): The name of the folder (relative to the parent of the current working
                        directory under the "coding_schemes" directory) containing the prompt files.

    Returns:
        tuple[str, str, str]: A tuple containing three strings:
            - PROMPT_SYSTEM: The content of `prompt_system.txt`.
            - PROMPT_USER: The content of `prompt_user.txt`.
            - PROMPT_AGENT: The content of `prompt_agent.txt`.

    '''
    path = Path(os.getcwd()) / folder
    # Read the three prompts
    PROMPT_SYSTEM_NAME = path / 'prompt_system.txt'
    PROMPT_USER_NAME = path / 'prompt_user.txt'
    PROMPT_AGENT_NAME = path / 'prompt_user.txt'
    
    # Get the system, user and agent prompts as a string
    with open(PROMPT_SYSTEM_NAME) as f:
        PROMPT_SYSTEM= f.read()

    with open(PROMPT_USER_NAME) as f:
        PROMPT_USER = f.read()

    with open(PROMPT_AGENT_NAME) as f:
        PROMPT_AGENT = f.read()
    # Return a tuple with the prompts
    return (PROMPT_SYSTEM, PROMPT_USER, PROMPT_AGENT)

# For error capturing
errors = []

# %% [markdown]
# ### Transformation json en df

# %%
def convert_to_dataframe(list_of_json: list, 
                        label_columns: list):

    '''
    Converts a list of JSON strings into a flattened Pandas DataFrame.

    This function processes a list of JSON strings, each representing a conversation with
    messages and annotations. It flattens the nested structure of the JSON and constructs
    a DataFrame with columns for activity ID, user ID, message metadata, and annotations.

    Args:
        list_of_json (list): A list of JSON strings, where each string represents a conversation.
        label_column (str): The name of the column to store annotations (e.g., labels).

    Returns:
        pd.DataFrame: A DataFrame containing the flattened conversation data with columns:
            - activity_id: The ID of the activity.
            - user_id: The ID of the user.
            - role: The role of the speaker (e.g., user, model).
            - message_num: The message number in the conversation.
            - utterance_num: The utterance number within the same message and role.
            - sentence_en: The English sentence of the message.
            - <label_column>: The annotation or label for the message.

    Raises:
        JSONDecodeError: If a JSON string cannot be decoded using `json.loads`.
        demjson3.JSONDecodeError: If a JSON string cannot be decoded using `demjson3.decode`.
    '''
    # A list to save every entry (row for our dataframe)
    flattened_data = []

    for entry in list_of_json:
        # First try to decode the string using vanilla JSON module
        try: 
            # Try to do the conversion 
            json_entry = json.loads(entry)

        # In case of error use demjson3 which is capable to deal
        # with JSON-like string (that use single quotes instead of double quotes)
        except:
            # Print the entry that trigger the exception for manual inspection 
            print(entry)
            try:
                json_entry = demjson3.decode(entry)
            except:
                continue

        # Get the IDs of the activity and the conversation
        seance_id = json_entry['seance_ID']
        groupe_id = json_entry['groupe_ID']
        # For every utterance in the conversation
        for message in json_entry['conversation']:
            # Create an entry (row) to use then in the dataframe
            try:
                flattened_data.append({
                    'seance_ID' : seance_id,
                    'groupe_ID': groupe_id,
                    'file_ID': map_messageId_fileId[message['messageID']],
                    'messageID': message['messageID'],
                    'role': message['role'],
                    'message': message['message'],
                    label_columns[0] : message['annotation']['form'],    #ajouter ici les autres attributs
                    label_columns[1] : message['annotation']['tone'],
                    label_columns[2] : message['annotation']['content'],
                    label_columns[3] : message['annotation']['nature'],
                    label_columns[4] : message['annotation']['form2']
                })

            except KeyError as key_error:
                # DEBUG
                print(str(message['messageID']) + " is missing a key : " + str(key_error))

    # Convert the entries in a dataframe
    out_df = pd.DataFrame(flattened_data)
    # Calculate an index for each utterance
    out_df['utterance_num'] = out_df.groupby(['groupe_ID', 'messageID', 'role']).cumcount()
    # Sort the columns of the dataframe
    out_df = out_df[['seance_ID', 'groupe_ID', 'file_ID', 'role', 
                        'messageID', 'utterance_num','message', label_columns[0],label_columns[1],label_columns[2],label_columns[3],label_columns[4]]]
    return out_df

# %% [markdown]
# ### Variables

# %%
# Reprise de la même architecture que celle utilisée par Luciano

PROMPT_FOLDER_OPENAI = 'prompts_openai'
PROMPT_FOLDER_MISTRAL = 'prompts_mistral'
PROMPT_FOLDER_MISTRAL_VOUVOIEMENT = 'prompts_mistral_vouvoiement'
PROMPT_FOLDER_MISTRAL_FORMV2 = 'prompts_mistral_form_v2'
OUT_FILE = 'dialogue_acts_example' + '.csv'
OUT_FOLDER = 'labeled_conversations'
LABEL_COLUMN_1 = 'forme'
LABEL_COLUMN_2 = 'ton'
LABEL_COLUMN_3 = 'content'
LABEL_COLUMN_4 = 'nature'
LABEL_COLUMN_5 = 'formv2'
#ajouter ici les autres labels des attributs
CATEGORY_COLUMN = 'type'

# %% [markdown]
# # Classification automatique : en utilisant une API Open AI

# %% [markdown]
# Code de Luciano : https://github.com/Lucky-Hidalgo/IRIT_Few-Shot-Tagging-Example

# %%
# %pip install pandas
# %pip install python-dotenv
# %pip install openai
# %pip install tqdm
# %pip install demjson3

clear_output()

# %% [markdown]
# ## Fonctions pour la classification

# %%
def classify_sentences(client: OpenAI, 
                        message: str,
                        prompt_system: str,
                        prompt_user: str,
                        prompt_agent: str):
    
    '''
    Classifies a given message using an OpenAI model with predefined prompts.

    This function sends a message to the OpenAI API along with system, user, and agent prompts
    to generate a classification response. It handles errors by logging them and returning `None`
    if the classification fails.

    Args:
        client (OpenAI): An instance of the OpenAI client used to interact with the API.
        message (str): The message to be classified.
        prompt_system (str): The system prompt to guide the model's behavior.
        prompt_user (str): The user prompt to provide context or instructions.
        prompt_agent (str): The agent prompt to simulate the assistant's role.

    Returns:
        str: The content of the model's response if the classification is successful.
        None: If an error occurs during the classification process.
    '''
    # Docs: https://platform.openai.com/docs/api-reference/chat/create 
    # It is possible to thinker with different parameters such as  response_format, seed,
    # frequency_penalty and so on, but in this case we specified:
    # Model which is going to do the classification, in this case gpt-4o-mini
    # The messages:
    #   - The system message is the task and role of the model
    #   - The user message is an example of an expected input to feed the model
    #   - The agent message is an example of an expected output for the provided model
    #   - The second user message is the text to label (The dictionary with the entire conversation)
    # Temperature: Set to zero to provide an output a bit more deterministic, but is not guaranteed to
    #              be deterministic (For that you should use a seed, which is in beta right now)
    # Stream: Set to False, to only recieve the entire response message, to avoid processing the stream after
    # Timeout: Set to 25 minutes, because conversations can take a lot of time to process.
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": prompt_system},
            {"role": "user", "content": prompt_user},
            {"role": "assistant", "content": prompt_agent},
            {"role": "user", "content": message}
        ],
        temperature=0,
        stream=False,
        timeout=1500  # Set the timeout to 1500 seconds
    )

    # Capture errors
    try:
        # If not error, we get the response
        return response.choices[0].message.content
    except:
        # If error, the function returns None, but the error message is appended
        # to a global array
        errors.append({'message': message, 'response': response})
        return None


def classify_conversation(openai_client: OpenAI,
                            prompt_system: str,
                            prompt_user: str,
                            prompt_agent: str,
                            conversations: list):
    '''
    Classifies a list of conversations using an OpenAI model with predefined prompts.

    This function iterates over a list of conversations, classifies each one using the
    `classify_sentences` function, and collects the results. A progress bar is displayed
    to track the classification process.

    Args:
        openai_client (OpenAI): An instance of the OpenAI client used to interact with the API.
        prompt_system (str): The system prompt to guide the model's behavior.
        prompt_user (str): The user prompt to provide context or instructions.
        prompt_agent (str): The agent prompt to simulate the assistant's role.
        conversations (list): A list of conversations (strings) to be classified.

    Returns:
        list: A list of classification results corresponding to each conversation. Each result
                is the output of the `classify_sentences` function, which may be a string or `None`
                if an error occurred during classification.
    '''

    out = []
    for conversation in tqdm(conversations, desc='Classifying...'):
        response = classify_sentences(openai_client, 
                                        str(conversation), 
                                        prompt_system, 
                                        prompt_user, 
                                        prompt_agent)
        out.append(response)
    return out

# %% [markdown]
# ## Instanciation du client Open AI et appel de la fonction pour classifier

# %%
f = open("env.txt")
key = f.read()
f.close()
key = key[15:]

# %%
# Load my OPEN AI API Key
load_dotenv() 

# Save value of OPEN AI API KEY to a variable
#OPENAI_KEY = os.getenv("OPENAI_API_KEY")

# Create an instance of the OPEN AI client using the API key
openai_client = OpenAI(api_key=key)   

# Read the prompts
prompt_system, prompt_user, prompt_agent = read_prompts(PROMPT_FOLDER_OPENAI)

# %%
# Do the classification
labeled_data = classify_conversation(openai_client,
                                    prompt_system,
                                    prompt_user,
                                    prompt_agent,
                                    conversations_dict[:5]) #modifier ici pour la data in
# Out:
# Classifying...:  20%|██        | 1/5 [00:06<00:26,  6.72s/it]
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[51], line 2
#       1 # Do the classification
# ----> 2 labeled_data = classify_conversation(openai_client,
#       3                                     prompt_system,
#       4                                     prompt_user,
#       5                                     prompt_agent,
#       6                                     conversations_dict[:5])
#
# Cell In[44], line 89, in classify_conversation(openai_client, prompt_system, prompt_user, prompt_agent, conversations)
#      87 out = []
#      88 for conversation in tqdm(conversations, desc='Classifying...'):
# ---> 89     response = classify_sentences(openai_client,
#      90                                     str(conversation),
#      91                                     prompt_system,
#      92                                     prompt_user,
#      93                                     prompt_agent)
#      94     out.append(response)
#      95 return out
#
# Cell In[44], line 38, in classify_sentences(client, message, prompt_system, prompt_user, prompt_agent)
#       7 '''
#       8 Classifies a given message using an OpenAI model with predefined prompts.
#       9
#    (...)
#      23     None: If an error occurs during the classification process.
#      24 '''
#      25 # Docs: https://platform.openai.com/docs/api-reference/chat/create
#      26 # It is possible to thinker with different parameters such as  response_format, seed,
#      27 # frequency_penalty and so on, but in this case we specified:
#    (...)
#      36 # Stream: Set to False, to only recieve the entire response message, to avoid processing the stream after
#      37 # Timeout: Set to 25 minutes, because conversations can take a lot of time to process.
# ---> 38 response = client.chat.completions.create(
#      39     model="gpt-4o-mini",
#      40     messages=[
#      41         {"role": "system", "content": prompt_system},
#      42         {"role": "user", "content": prompt_user},
#      43         {"role": "assistant", "content": prompt_agent},
#      44         {"role": "user", "content": message}
#      45     ],
#      46     temperature=0,
#      47     stream=False,
#      48     timeout=1500  # Set the timeout to 1500 seconds
#      49 )
#      51 # Capture errors
#      52 try:
#      53     # If not error, we get the response
#
# File c:\Users\cbd65\anaconda3\envs\jupyterenv\lib\site-packages\openai\_utils\_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File c:\Users\cbd65\anaconda3\envs\jupyterenv\lib\site-packages\openai\resources\chat\completions\completions.py:879, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     837 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     838 def create(
#     839     self,
#    (...)
#     876     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     877 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     878     validate_response_format(response_format)
# --> 879     return self._post(
#     880         "/chat/completions",
#     881         body=maybe_transform(
#     882             {
#     883                 "messages": messages,
#     884                 "model": model,
#     885                 "audio": audio,
#     886                 "frequency_penalty": frequency_penalty,
#     887                 "function_call": function_call,
#     888                 "functions": functions,
#     889                 "logit_bias": logit_bias,
#     890                 "logprobs": logprobs,
#     891                 "max_completion_tokens": max_completion_tokens,
#     892                 "max_tokens": max_tokens,
#     893                 "metadata": metadata,
#     894                 "modalities": modalities,
#     895                 "n": n,
#     896                 "parallel_tool_calls": parallel_tool_calls,
#     897                 "prediction": prediction,
#     898                 "presence_penalty": presence_penalty,
#     899                 "reasoning_effort": reasoning_effort,
#     900                 "response_format": response_format,
#     901                 "seed": seed,
#     902                 "service_tier": service_tier,
#     903                 "stop": stop,
#     904                 "store": store,
#     905                 "stream": stream,
#     906                 "stream_options": stream_options,
#     907                 "temperature": temperature,
#     908                 "tool_choice": tool_choice,
#     909                 "tools": tools,
#     910                 "top_logprobs": top_logprobs,
#     911                 "top_p": top_p,
#     912                 "user": user,
#     913             },
#     914             completion_create_params.CompletionCreateParams,
#     915         ),
#     916         options=make_request_options(
#     917             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     918         ),
#     919         cast_to=ChatCompletion,
#     920         stream=stream or False,
#     921         stream_cls=Stream[ChatCompletionChunk],
#     922     )
#
# File c:\Users\cbd65\anaconda3\envs\jupyterenv\lib\site-packages\openai\_base_client.py:1290, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1276 def post(
#    1277     self,
#    1278     path: str,
#    (...)
#    1285     stream_cls: type[_StreamT] | None = None,
#    1286 ) -> ResponseT | _StreamT:
#    1287     opts = FinalRequestOptions.construct(
#    1288         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1289     )
# -> 1290     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\cbd65\anaconda3\envs\jupyterenv\lib\site-packages\openai\_base_client.py:967, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     964 else:
#     965     retries_taken = 0
# --> 967 return self._request(
#     968     cast_to=cast_to,
#     969     options=options,
#     970     stream=stream,
#     971     stream_cls=stream_cls,
#     972     retries_taken=retries_taken,
#     973 )
#
# File c:\Users\cbd65\anaconda3\envs\jupyterenv\lib\site-packages\openai\_base_client.py:1056, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1054 if remaining_retries > 0 and self._should_retry(err.response):
#    1055     err.response.close()
# -> 1056     return self._retry_request(
#    1057         input_options,
#    1058         cast_to,
#    1059         retries_taken=retries_taken,
#    1060         response_headers=err.response.headers,
#    1061         stream=stream,
#    1062         stream_cls=stream_cls,
#    1063     )
#    1065 # If the response is streamed then we need to explicitly read the response
#    1066 # to completion before attempting to access the response text.
#    1067 if not err.response.is_closed:
#
# File c:\Users\cbd65\anaconda3\envs\jupyterenv\lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1101 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1102 # different thread if necessary.
#    1103 time.sleep(timeout)
# -> 1105 return self._request(
#    1106     options=options,
#    1107     cast_to=cast_to,
#    1108     retries_taken=retries_taken + 1,
#    1109     stream=stream,
#    1110     stream_cls=stream_cls,
#    1111 )
#
# File c:\Users\cbd65\anaconda3\envs\jupyterenv\lib\site-packages\openai\_base_client.py:1056, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1054 if remaining_retries > 0 and self._should_retry(err.response):
#    1055     err.response.close()
# -> 1056     return self._retry_request(
#    1057         input_options,
#    1058         cast_to,
#    1059         retries_taken=retries_taken,
#    1060         response_headers=err.response.headers,
#    1061         stream=stream,
#    1062         stream_cls=stream_cls,
#    1063     )
#    1065 # If the response is streamed then we need to explicitly read the response
#    1066 # to completion before attempting to access the response text.
#    1067 if not err.response.is_closed:
#
# File c:\Users\cbd65\anaconda3\envs\jupyterenv\lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1101 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1102 # different thread if necessary.
#    1103 time.sleep(timeout)
# -> 1105 return self._request(
#    1106     options=options,
#    1107     cast_to=cast_to,
#    1108     retries_taken=retries_taken + 1,
#    1109     stream=stream,
#    1110     stream_cls=stream_cls,
#    1111 )
#
# File c:\Users\cbd65\anaconda3\envs\jupyterenv\lib\site-packages\openai\_base_client.py:1071, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1068         err.response.read()
#    1070     log.debug("Re-raising status error")
# -> 1071     raise self._make_status_error_from_response(err.response) from None
#    1073 return self._process_response(
#    1074     cast_to=cast_to,
#    1075     options=options,
#    (...)
#    1079     retries_taken=retries_taken,
#    1080 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-Hb86CiMZyMYd9WwCXvjB4As5 on requests per min (RPM): Limit 3, Used 3, Requested 1. Please try again in 20s. Visit https://platform.openai.com/account/rate-limits to learn more. You can increase your rate limit by adding a payment method to your account at https://platform.openai.com/account/billing.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}

# %%
print(labeled_data[3])
# Out:
# {
#   "seance_ID": "np.int64(1)",
#   "groupe_ID": "np.int64(3)",
#   "conversation": [
#     {
#       "messageID": 15,
#       "role": "Driver",
#       "message": "je ne sais pas comment voir le résultat ",
#       "annotation": {
#         "form": "negativeSentence",
#         "tone": "positiveTone",
#         "content": "notRelatedToProgramming_Other",
#         "nature": "noFeedback"
#       }
#     },
#     {
#       "messageID": 16,
#       "role": "Navigator",
#       "message": "faut mettre print(coincide)",
#       "annotation": {
#         "form": "imperativeSentence",
#         "tone": "positiveTone",
#         "content": "relatedToProgramming_relatedToTask",
#         "nature": "correctResponse"
#       }
#     },
#     {
#       "messageID": 17,
#       "role": "Driver",
#       "message": "essaye",
#       "annotation": {
#         "form": "imperativeSentence",
#         "tone": "positiveTone",
#         "content": "notRelatedToProgramming_Other",
#         "nature": "noFeedback"
#       }
#     },
#     {
#       "messageID": 18,
#       "role": "Navigator",
#       "message": "attend",
#       "annotation": {
#         "form": "imperativeSentence",
#         "tone": "positiveTone",
#         "content": "notRelatedToProgramming_Other",
#         "nature": "noFeedback"
#       }
#     },
#     {
#       "messageID": 19,
#       "role": "Driver",
#       "message": "je crois que c'est bon",
#       "annotation": {
#         "form": "positiveSentence",
#         "tone": "positiveTone",
#         "content": "notRelatedToProgramming_Other",
#         "nature": "responseValidity"
#       }
#     },
#     {
#       "messageID": 20,
#       "role": "Navigator",
#       "message": "attend",
#       "annotation": {
#         "form": "imperativeSentence",
#         "tone": "positiveTone",
#         "content": "notRelatedToProgramming_Other",
#         "nature": "noFeedback"
#       }
#     },
#     {
#       "messageID": 21,
#       "role": "Navigator",
#       "message": "attend",
#       "annotation": {
#         "form": "imperativeSentence",
#         "tone": "positiveTone",
#         "content": "notRelatedToProgramming_Other",
#         "nature": "noFeedback"
#       }
#     }
#   ]
# }

# %%
errors
# Out:
# []

# %%
out_df = convert_to_dataframe(labeled_data, [LABEL_COLUMN_1,LABEL_COLUMN_2,LABEL_COLUMN_3,LABEL_COLUMN_4])

out_df
# Out:
#       seance_ID    groupe_ID       role  messageID  utterance_num  \
# 0             1            0  Navigator          0              0
# 1             1            0  Navigator          1              0
# 2   np.int64(1)  np.int64(1)     Driver          2              0
# 3   np.int64(1)  np.int64(1)     Driver          3              0
# 4   np.int64(1)  np.int64(1)  Navigator          4              0
# 5   np.int64(1)  np.int64(1)  Navigator          5              0
# 6   np.int64(1)  np.int64(1)  Navigator          6              0
# 7   np.int64(1)  np.int64(1)  Navigator          7              0
# 8   np.int64(1)  np.int64(1)  Navigator          8              0
# 9   np.int64(1)  np.int64(1)  Navigator          9              0
# 10  np.int64(1)  np.int64(1)  Navigator         10              0
# 11  np.int64(1)  np.int64(1)  Navigator         11              0
# 12  np.int64(1)  np.int64(1)  Navigator         12              0
# 13            1            2     Driver         13              0
# 14            1            2     Driver         14              0
# 15  np.int64(1)  np.int64(3)     Driver         15              0
# 16  np.int64(1)  np.int64(3)  Navigator         16              0
# 17  np.int64(1)  np.int64(3)     Driver         17              0
# 18  np.int64(1)  np.int64(3)  Navigator         18              0
# 19  np.int64(1)  np.int64(3)     Driver         19              0
# 20  np.int64(1)  np.int64(3)  Navigator         20              0
# 21  np.int64(1)  np.int64(3)  Navigator         21              0
# 22  np.int64(1)  np.int64(4)     Driver         22              0
# 23  np.int64(1)  np.int64(4)  Navigator         23              0
# 24  np.int64(1)  np.int64(4)     Driver         24              0
# 25  np.int64(1)  np.int64(4)  Navigator         25              0
# 26  np.int64(1)  np.int64(4)     Driver         26              0
# 27  np.int64(1)  np.int64(4)  Navigator         27              0
# 28  np.int64(1)  np.int64(4)     Driver         28              0
# 29  np.int64(1)  np.int64(4)  Navigator         29              0
# 30  np.int64(1)  np.int64(4)  Navigator         30              0
# 31  np.int64(1)  np.int64(4)     Driver         31              0
# 32  np.int64(1)  np.int64(4)     Driver         32              0
# 33  np.int64(1)  np.int64(4)  Navigator         33              0
# 34  np.int64(1)  np.int64(4)  Navigator         34              0
# 35  np.int64(1)  np.int64(4)  Navigator         35              0
# 36  np.int64(1)  np.int64(4)  Navigator         36              0
# 37  np.int64(1)  np.int64(4)     Driver         37              0
# 38  np.int64(1)  np.int64(4)  Navigator         38              0
# 39  np.int64(1)  np.int64(4)     Driver         39              0
# 40  np.int64(1)  np.int64(4)     Driver         40              0
# 41  np.int64(1)  np.int64(4)  Navigator         41              0
# 42  np.int64(1)  np.int64(4)     Driver         42              0
# 43  np.int64(1)  np.int64(4)     Driver         43              0
# 44  np.int64(1)  np.int64(4)  Navigator         44              0
# 45  np.int64(1)  np.int64(4)  Navigator         45              0
# 46  np.int64(1)  np.int64(4)  Navigator         46              0
#
#                                               message               forme  \
# 0                                         Tu es qui ,            question
# 1                            On se met 5 partout ok ?            question
# 2                                                 Opé    positiveSentence
# 3                                            Opé lmkt    positiveSentence
# 4                                   A PAR SA LE COUZ     positiveSentence
# 5                                                Opé     positiveSentence
# 6                                      Ou lé jolie ?             question
# 7                                               A ou     positiveSentence
# 8                                           Commencé     positiveSentence
# 9                                 Comment nous fé la             question
# 10                               c'est kwé faut fait     positiveSentence
# 11                          Lève ton main un coup la   imperativeSentence
# 12                           aide a moins un coup la   imperativeSentence
# 13                                               roro    positiveSentence
# 14                                         Qui est là            question
# 15           je ne sais pas comment voir le résultat     negativeSentence
# 16                        faut mettre print(coincide)  imperativeSentence
# 17                                             essaye  imperativeSentence
# 18                                             attend  imperativeSentence
# 19                             je crois que c'est bon    positiveSentence
# 20                                             attend  imperativeSentence
# 21                                             attend  imperativeSentence
# 22                                            Bonjour    positiveSentence
# 23                                            Bonjour    positiveSentence
# 24  tu pense si je fais un for in in range avec un...            question
# 25                                               oui     positiveSentence
# 26                                    tu veux editer?            question
# 27                                      comme tu veux    positiveSentence
# 28               je teste si ça marche pas on echange    positiveSentence
# 29                                               vsy     positiveSentence
# 30  en vrai c'est pas mieux de faire un "if len(a)...    negativeSentence
# 31                                     tu veux teste?            question
# 32                                  demande l'édition  imperativeSentence
# 33                               vsy je teste le code    positiveSentence
# 34  quand je teste le code il me disent y'a des er...    positiveSentence
# 35                                           pour int    positiveSentence
# 36                                     je sais pas pk    negativeSentence
# 37  demande a éditer je te passe la main tu teste ...  imperativeSentence
# 38  vsy je sauvegarde juste le ocde que t'a déja fait    positiveSentence
# 39                                                 ok    positiveSentence
# 40                                        je supprime    positiveSentence
# 41                                 c bon t'as la main    positiveSentence
# 42               je crois c'est bon , je suis pas sur    positiveSentence
# 43                                    tu peux tester?            question
# 44  il y a des erreurs sur plusieurs lignes mais l...    positiveSentence
# 45                            sur le return positions    positiveSentence
# 46                         on fini l'activité ducoup?            question
#
#              ton                                  content            nature
# 0   positiveTone            notRelatedToProgramming_Other        noFeedback
# 1   positiveTone            notRelatedToProgramming_Other        noFeedback
# 2   positiveTone            notRelatedToProgramming_Other        noFeedback
# 3   positiveTone            notRelatedToProgramming_Other        noFeedback
# 4   positiveTone            notRelatedToProgramming_Other        noFeedback
# 5   positiveTone            notRelatedToProgramming_Other        noFeedback
# 6   positiveTone            notRelatedToProgramming_Other        noFeedback
# 7   positiveTone            notRelatedToProgramming_Other        noFeedback
# 8   positiveTone            notRelatedToProgramming_Other        noFeedback
# 9   positiveTone            notRelatedToProgramming_Other        noFeedback
# 10  positiveTone            notRelatedToProgramming_Other        noFeedback
# 11  positiveTone            notRelatedToProgramming_Other        noFeedback
# 12  positiveTone            notRelatedToProgramming_Other        noFeedback
# 13  positiveTone            notRelatedToProgramming_Other        noFeedback
# 14  positiveTone            notRelatedToProgramming_Other        noFeedback
# 15  positiveTone            notRelatedToProgramming_Other        noFeedback
# 16  positiveTone       relatedToProgramming_relatedToTask   correctResponse
# 17  positiveTone            notRelatedToProgramming_Other        noFeedback
# 18  positiveTone            notRelatedToProgramming_Other        noFeedback
# 19  positiveTone            notRelatedToProgramming_Other  responseValidity
# 20  positiveTone            notRelatedToProgramming_Other        noFeedback
# 21  positiveTone            notRelatedToProgramming_Other        noFeedback
# 22  positiveTone            notRelatedToProgramming_Other        noFeedback
# 23  positiveTone            notRelatedToProgramming_Other        noFeedback
# 24  positiveTone       relatedToProgramming_relatedToTask      howToProceed
# 25  positiveTone            notRelatedToProgramming_Other        noFeedback
# 26  positiveTone  notRelatedToProgramming_relativeToRoles        noFeedback
# 27  positiveTone            notRelatedToProgramming_Other        noFeedback
# 28  positiveTone            notRelatedToProgramming_Other        noFeedback
# 29  positiveTone            notRelatedToProgramming_Other        noFeedback
# 30  positiveTone       relatedToProgramming_relatedToTask      howToProceed
# 31  positiveTone  notRelatedToProgramming_relativeToRoles        noFeedback
# 32  positiveTone  notRelatedToProgramming_relativeToRoles        noFeedback
# 33  positiveTone       relatedToProgramming_relatedToTask        noFeedback
# 34  positiveTone       relatedToProgramming_relatedToTask            errors
# 35  positiveTone            notRelatedToProgramming_Other        noFeedback
# 36  positiveTone            notRelatedToProgramming_Other        noFeedback
# 37  positiveTone  notRelatedToProgramming_relativeToRoles        noFeedback
# 38  positiveTone       relatedToProgramming_relatedToTask        noFeedback
# 39  positiveTone            notRelatedToProgramming_Other        noFeedback
# 40  positiveTone       relatedToProgramming_relatedToTask        noFeedback
# 41  positiveTone  notRelatedToProgramming_relativeToRoles        noFeedback
# 42  positiveTone            notRelatedToProgramming_Other        noFeedback
# 43  positiveTone  notRelatedToProgramming_relativeToRoles        noFeedback
# 44  positiveTone       relatedToProgramming_relatedToTask            errors
# 45  positiveTone       relatedToProgramming_relatedToTask            errors
# 46  positiveTone            notRelatedToProgramming_Other        noFeedback

# %%
out_df.to_csv("annotation_openai_conv_0_to_5.csv")

# %%
out_df.iloc[34]
# Out:
# seance_ID                                              np.int64(1)
# groupe_ID                                              np.int64(4)
# role                                                     Navigator
# messageID                                                       34
# utterance_num                                                    0
# message          quand je teste le code il me disent y'a des er...
# forme                                             positiveSentence
# ton                                                   positiveTone
# content                         relatedToProgramming_relatedToTask
# nature                                                      errors
# Name: 34, dtype: object

# %%
out_df.iloc[34]['message']
# Out:
# "quand je teste le code il me disent y'a des erreurs de type"

# %%
out_df.iloc[42]
# Out:
# seance_ID                                 np.int64(1)
# groupe_ID                                 np.int64(4)
# role                                           Driver
# messageID                                          42
# utterance_num                                       0
# message          je crois c'est bon , je suis pas sur
# forme                                positiveSentence
# ton                                      positiveTone
# content                 notRelatedToProgramming_Other
# nature                                     noFeedback
# Name: 42, dtype: object

# %%
out_df.iloc[44]
# Out:
# seance_ID                                              np.int64(1)
# groupe_ID                                              np.int64(4)
# role                                                     Navigator
# messageID                                                       44
# utterance_num                                                    0
# message          il y a des erreurs sur plusieurs lignes mais l...
# forme                                             positiveSentence
# ton                                                   positiveTone
# content                         relatedToProgramming_relatedToTask
# nature                                                      errors
# Name: 44, dtype: object

# %%
out_df.iloc[44]['message']
# Out:
# "il y a des erreurs sur plusieurs lignes mais le dernier j'ai pas"

# %%
out_df.to_csv("classified_test.csv")

# %% [markdown]
# ## Messages de test

# %%
test_message = [{'seance_ID': np.int64(99),
 'groupe_ID': np.int64(99),
 'conversation': [{'messageID': 99,
   'role': 'Navigator',
   'message': 'va plus vite tes trop lent'}]}]

# %%
prompt_system, prompt_user, prompt_agent = read_prompts(PROMPT_FOLDER_OPENAI)

# %%
test_df = classify_conversation(openai_client,
                                  prompt_system,
                                     prompt_user,
                                     prompt_agent,
                                     [conversations_dict[4]])
# Out:
# Classifying...: 100%|██████████| 1/1 [00:28<00:00, 28.41s/it]

# %%
test_df
# Out:
# ['{\n  "seance_ID": "np.int64(1)",\n  "groupe_ID": "np.int64(4)",\n  "conversation": [\n    {\n      "messageID": 22,\n      "role": "Driver",\n      "message": "Bonjour",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 23,\n      "role": "Navigator",\n      "message": "Bonjour",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 24,\n      "role": "Driver",\n      "message": "tu pense si je fais un for in in range avec un for j in range dedans ça peut marcher? ",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 25,\n      "role": "Navigator",\n      "message": "oui ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 26,\n      "role": "Driver",\n      "message": "tu veux editer?",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_relativeToRoles",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 27,\n      "role": "Navigator",\n      "message": "comme tu veux",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 28,\n      "role": "Driver",\n      "message": "je teste si ça marche pas on echange",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 29,\n      "role": "Navigator",\n      "message": "vsy ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 30,\n      "role": "Navigator",\n      "message": "en vrai c\'est pas mieux de faire un \\"if len(a) != len(b)\\"",\n      "annotation": {\n        "form": "negativeSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "howToProceed"\n      }\n    },\n    {\n      "messageID": 31,\n      "role": "Driver",\n      "message": "tu veux teste?",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_relativeToRoles",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 32,\n      "role": "Driver",\n      "message": "demande l\'édition",\n      "annotation": {\n        "form": "imperativeSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_relativeToRoles",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 33,\n      "role": "Navigator",\n      "message": "vsy je teste le code",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 34,\n      "role": "Navigator",\n      "message": "quand je teste le code il me disent y\'a des erreurs de type",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature ...

# %%
out_test_df = convert_to_dataframe(test_df, [LABEL_COLUMN_1,LABEL_COLUMN_2,LABEL_COLUMN_3,LABEL_COLUMN_4])
out_test_df
# Out:
#       seance_ID    groupe_ID       role  messageID  utterance_num  \
# 0   np.int64(1)  np.int64(4)     Driver         22              0
# 1   np.int64(1)  np.int64(4)  Navigator         23              0
# 2   np.int64(1)  np.int64(4)     Driver         24              0
# 3   np.int64(1)  np.int64(4)  Navigator         25              0
# 4   np.int64(1)  np.int64(4)     Driver         26              0
# 5   np.int64(1)  np.int64(4)  Navigator         27              0
# 6   np.int64(1)  np.int64(4)     Driver         28              0
# 7   np.int64(1)  np.int64(4)  Navigator         29              0
# 8   np.int64(1)  np.int64(4)  Navigator         30              0
# 9   np.int64(1)  np.int64(4)     Driver         31              0
# 10  np.int64(1)  np.int64(4)     Driver         32              0
# 11  np.int64(1)  np.int64(4)  Navigator         33              0
# 12  np.int64(1)  np.int64(4)  Navigator         34              0
# 13  np.int64(1)  np.int64(4)  Navigator         35              0
# 14  np.int64(1)  np.int64(4)  Navigator         36              0
# 15  np.int64(1)  np.int64(4)     Driver         37              0
# 16  np.int64(1)  np.int64(4)  Navigator         38              0
# 17  np.int64(1)  np.int64(4)     Driver         39              0
# 18  np.int64(1)  np.int64(4)     Driver         40              0
# 19  np.int64(1)  np.int64(4)  Navigator         41              0
# 20  np.int64(1)  np.int64(4)     Driver         42              0
# 21  np.int64(1)  np.int64(4)     Driver         43              0
# 22  np.int64(1)  np.int64(4)  Navigator         44              0
# 23  np.int64(1)  np.int64(4)  Navigator         45              0
# 24  np.int64(1)  np.int64(4)  Navigator         46              0
#
#                                               message               forme  \
# 0                                             Bonjour    positiveSentence
# 1                                             Bonjour    positiveSentence
# 2   tu pense si je fais un for in in range avec un...            question
# 3                                                oui     positiveSentence
# 4                                     tu veux editer?            question
# 5                                       comme tu veux    positiveSentence
# 6                je teste si ça marche pas on echange    positiveSentence
# 7                                                vsy     positiveSentence
# 8   en vrai c'est pas mieux de faire un "if len(a)...    negativeSentence
# 9                                      tu veux teste?            question
# 10                                  demande l'édition  imperativeSentence
# 11                               vsy je teste le code    positiveSentence
# 12  quand je teste le code il me disent y'a des er...    positiveSentence
# 13                                           pour int    positiveSentence
# 14                                     je sais pas pk    negativeSentence
# 15  demande a éditer je te passe la main tu teste ...  imperativeSentence
# 16  vsy je sauvegarde juste le ocde que t'a déja fait    positiveSentence
# 17                                                 ok    positiveSentence
# 18                                        je supprime    positiveSentence
# 19                                 c bon t'as la main    positiveSentence
# 20               je crois c'est bon , je suis pas sur    positiveSentence
# 21                                    tu peux tester?            question
# 22  il y a des erreurs sur plusieurs lignes mais l...    positiveSentence
# 23                            sur le return positions    positiveSentence
# 24                         on fini l'activité ducoup?            question
#
#              ton                                  content            nature
# 0   positiveTone            notRelatedToProgramming_Other        noFeedback
# 1   positiveTone            notRelatedToProgramming_Other        noFeedback
# 2   positiveTone       relatedToProgramming_relatedToTask        noFeedback
# 3   positiveTone            notRelatedToProgramming_Other        noFeedback
# 4   positiveTone  notRelatedToProgramming_relativeToRoles        noFeedback
# 5   positiveTone            notRelatedToProgramming_Other        noFeedback
# 6   positiveTone            notRelatedToProgramming_Other        noFeedback
# 7   positiveTone            notRelatedToProgramming_Other        noFeedback
# 8   positiveTone       relatedToProgramming_relatedToTask      howToProceed
# 9   positiveTone  notRelatedToProgramming_relativeToRoles        noFeedback
# 10  positiveTone  notRelatedToProgramming_relativeToRoles        noFeedback
# 11  positiveTone       relatedToProgramming_relatedToTask        noFeedback
# 12  positiveTone       relatedToProgramming_relatedToTask            errors
# 13  positiveTone            notRelatedToProgramming_Other        noFeedback
# 14  positiveTone            notRelatedToProgramming_Other        noFeedback
# 15  positiveTone  notRelatedToProgramming_relativeToRoles        noFeedback
# 16  positiveTone    relatedToProgramming_notRelatedToTask        noFeedback
# 17  positiveTone            notRelatedToProgramming_Other        noFeedback
# 18  positiveTone       relatedToProgramming_relatedToTask        noFeedback
# 19  positiveTone  notRelatedToProgramming_relativeToRoles        noFeedback
# 20  positiveTone            notRelatedToProgramming_Other  responseValidity
# 21  positiveTone  notRelatedToProgramming_relativeToRoles        noFeedback
# 22  positiveTone       relatedToProgramming_relatedToTask            errors
# 23  positiveTone       relatedToProgramming_relatedToTask            errors
# 24  positiveTone            notRelatedToProgramming_Other        noFeedback

# %%
conversations_dict[6]
# Out:
# {'seance_ID': np.int64(1),
#  'groupe_ID': np.int64(7),
#  'conversation': [{'messageID': 49, 'role': 'Driver', 'message': 'Yo!'},
#   {'messageID': 50, 'role': 'Navigator', 'message': 'OUI'},
#   {'messageID': 51, 'role': 'Navigator', 'message': ',????'},
#   {'messageID': 52, 'role': 'Driver', 'message': 'Oui'},
#   {'messageID': 53, 'role': 'Navigator', 'message': "C'est bon pour toi"},
#   {'messageID': 54, 'role': 'Driver', 'message': "C'est bon"},
#   {'messageID': 55,
#    'role': 'Driver',
#    'message': 'Est ce que faut vérifié si les listes sont de la même longueur ?'},
#   {'messageID': 56,
#    'role': 'Navigator',
#    'message': 'def coincide(tableau1, tableau2):     # On s\'assure que les deux tableaux ont la même longueur     if len(tableau1) != len(tableau2):         return []      # On crée un tableau vide pour stocker les indices où les éléments sont identiques     result = []          # On parcourt les deux tableaux et on compare les éléments     for i in range(len(tableau1)):         if tableau1[i] == tableau2[i]:             result.append(i)      return result  # Exemples d\'utilisation : print(coincide([78, 23, 12, 12, 54, 32], [67, 23, 44, 12, 54, 32]))  # [1, 3, 4, 5] print(coincide(["antoine", "isaac", "denis"], ["jeanne", "sofiane", "lise"]))  # []'},
#   {'messageID': 57, 'role': 'Navigator', 'message': 'okok  je vois'},
#   {'messageID': 58, 'role': 'Navigator', 'message': 'nickel!'},
#   {'messageID': 59, 'role': 'Driver', 'message': 'je te donne la main'},
#   {'messageID': 60, 'role': 'Navigator', 'message': 'Merci!'},
#   {'messageID': 61,
#    'role': 'Driver',
#    'message': 'je met en commentaire mon morceau'},
#   {'messageID': 62, 'role': 'Navigator', 'message': 'ok'},
#   {'messageID': 63, 'role': 'Navigator', 'message': 'complete le tableau'},
#   {'messageID': 64,
#    'role': 'Driver',
#    'message': "wait, quand j'exécute ca fonctionne pas"},
#   {'messageID': 65,
#    'role': 'Driver',
#    'message': "je te donne la main, j'ai pas compris ce que tu m'as dit"},
#   {'messageID': 66, 'role': 'Navigator', 'message': "att c'est noramal"},
#   {'messageID': 67,
#    'role': 'Driver',
#    'message': 'ca bug, je peut plus donner la main'},
#   {'messageID': 68, 'role': 'Driver', 'message': 'hummm! regarde ca'},
#   {'messageID': 69, 'role': 'Driver', 'message': 'bon je sais pas pourquoi'},
#   {'messageID': 70, 'role': 'Driver', 'message': nan},
#   {'messageID': 71, 'role': 'Navigator', 'message': 'accepte'},
#   {'messageID': 72, 'role': 'Navigator', 'message': 'ok'},
#   {'messageID': 73,
#    'role': 'Navigator',
#    'message': 'ta pas besoin du return  []'},
#   {'messageID': 74, 'role': 'Navigator', 'message': 'bon on termine, tkt'},
#   {'messageID': 75, 'role': 'Navigator', 'message': "c'est ok "},
#   {'messageID': 76, 'role': 'Navigator', 'message': 'on fini'}]}

# %%
prompt_system, prompt_user, prompt_agent = read_prompts(PROMPT_FOLDER_OPENAI)

# %%
test_df = classify_conversation(openai_client,
                                  prompt_system,
                                     prompt_user,
                                     prompt_agent,
                                     [conversations_dict[6]])
# Out:
# Classifying...: 100%|██████████| 1/1 [00:37<00:00, 37.08s/it]

# %%
test_df
# Out:
# ['{\n  "seance_ID": "np.int64(1)",\n  "groupe_ID": "np.int64(4)",\n  "conversation": [\n    {\n      "messageID": 22,\n      "role": "Driver",\n      "message": "Bonjour",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 23,\n      "role": "Navigator",\n      "message": "Bonjour",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 24,\n      "role": "Driver",\n      "message": "tu pense si je fais un for in in range avec un for j in range dedans ça peut marcher? ",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 25,\n      "role": "Navigator",\n      "message": "oui ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 26,\n      "role": "Driver",\n      "message": "tu veux editer?",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_relativeToRoles",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 27,\n      "role": "Navigator",\n      "message": "comme tu veux",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 28,\n      "role": "Driver",\n      "message": "je teste si ça marche pas on echange",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 29,\n      "role": "Navigator",\n      "message": "vsy ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 30,\n      "role": "Navigator",\n      "message": "en vrai c\'est pas mieux de faire un \\"if len(a) != len(b)\\"",\n      "annotation": {\n        "form": "negativeSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "howToProceed"\n      }\n    },\n    {\n      "messageID": 31,\n      "role": "Driver",\n      "message": "tu veux teste?",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_relativeToRoles",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 32,\n      "role": "Driver",\n      "message": "demande l\'édition",\n      "annotation": {\n        "form": "imperativeSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_relativeToRoles",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 33,\n      "role": "Navigator",\n      "message": "vsy je teste le code",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 34,\n      "role": "Navigator",\n      "message": "quand je teste le code il me disent y\'a des erreurs de type",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature ...

# %%
out_test_df = convert_to_dataframe(test_df, [LABEL_COLUMN_1,LABEL_COLUMN_2,LABEL_COLUMN_3,LABEL_COLUMN_4])
out_test_df
# Out:
#       seance_ID    groupe_ID       role  messageID  utterance_num  \
# 0   np.int64(1)  np.int64(4)     Driver         22              0
# 1   np.int64(1)  np.int64(4)  Navigator         23              0
# 2   np.int64(1)  np.int64(4)     Driver         24              0
# 3   np.int64(1)  np.int64(4)  Navigator         25              0
# 4   np.int64(1)  np.int64(4)     Driver         26              0
# 5   np.int64(1)  np.int64(4)  Navigator         27              0
# 6   np.int64(1)  np.int64(4)     Driver         28              0
# 7   np.int64(1)  np.int64(4)  Navigator         29              0
# 8   np.int64(1)  np.int64(4)  Navigator         30              0
# 9   np.int64(1)  np.int64(4)     Driver         31              0
# 10  np.int64(1)  np.int64(4)     Driver         32              0
# 11  np.int64(1)  np.int64(4)  Navigator         33              0
# 12  np.int64(1)  np.int64(4)  Navigator         34              0
# 13  np.int64(1)  np.int64(4)  Navigator         35              0
# 14  np.int64(1)  np.int64(4)  Navigator         36              0
# 15  np.int64(1)  np.int64(4)     Driver         37              0
# 16  np.int64(1)  np.int64(4)  Navigator         38              0
# 17  np.int64(1)  np.int64(4)     Driver         39              0
# 18  np.int64(1)  np.int64(4)     Driver         40              0
# 19  np.int64(1)  np.int64(4)  Navigator         41              0
# 20  np.int64(1)  np.int64(4)     Driver         42              0
# 21  np.int64(1)  np.int64(4)     Driver         43              0
# 22  np.int64(1)  np.int64(4)  Navigator         44              0
# 23  np.int64(1)  np.int64(4)  Navigator         45              0
# 24  np.int64(1)  np.int64(4)  Navigator         46              0
#
#                                               message               forme  \
# 0                                             Bonjour    positiveSentence
# 1                                             Bonjour    positiveSentence
# 2   tu pense si je fais un for in in range avec un...            question
# 3                                                oui     positiveSentence
# 4                                     tu veux editer?            question
# 5                                       comme tu veux    positiveSentence
# 6                je teste si ça marche pas on echange    positiveSentence
# 7                                                vsy     positiveSentence
# 8   en vrai c'est pas mieux de faire un "if len(a)...    negativeSentence
# 9                                      tu veux teste?            question
# 10                                  demande l'édition  imperativeSentence
# 11                               vsy je teste le code    positiveSentence
# 12  quand je teste le code il me disent y'a des er...    positiveSentence
# 13                                           pour int    positiveSentence
# 14                                     je sais pas pk    negativeSentence
# 15  demande a éditer je te passe la main tu teste ...  imperativeSentence
# 16  vsy je sauvegarde juste le ocde que t'a déja fait    positiveSentence
# 17                                                 ok    positiveSentence
# 18                                        je supprime    positiveSentence
# 19                                 c bon t'as la main    positiveSentence
# 20               je crois c'est bon , je suis pas sur    positiveSentence
# 21                                    tu peux tester?            question
# 22  il y a des erreurs sur plusieurs lignes mais l...    positiveSentence
# 23                            sur le return positions    positiveSentence
# 24                         on fini l'activité ducoup?            question
#
#              ton                                  content            nature
# 0   positiveTone            notRelatedToProgramming_Other        noFeedback
# 1   positiveTone            notRelatedToProgramming_Other        noFeedback
# 2   positiveTone       relatedToProgramming_relatedToTask        noFeedback
# 3   positiveTone            notRelatedToProgramming_Other        noFeedback
# 4   positiveTone  notRelatedToProgramming_relativeToRoles        noFeedback
# 5   positiveTone            notRelatedToProgramming_Other        noFeedback
# 6   positiveTone            notRelatedToProgramming_Other        noFeedback
# 7   positiveTone            notRelatedToProgramming_Other        noFeedback
# 8   positiveTone       relatedToProgramming_relatedToTask      howToProceed
# 9   positiveTone  notRelatedToProgramming_relativeToRoles        noFeedback
# 10  positiveTone  notRelatedToProgramming_relativeToRoles        noFeedback
# 11  positiveTone       relatedToProgramming_relatedToTask        noFeedback
# 12  positiveTone       relatedToProgramming_relatedToTask            errors
# 13  positiveTone            notRelatedToProgramming_Other        noFeedback
# 14  positiveTone            notRelatedToProgramming_Other        noFeedback
# 15  positiveTone  notRelatedToProgramming_relativeToRoles        noFeedback
# 16  positiveTone    relatedToProgramming_notRelatedToTask        noFeedback
# 17  positiveTone            notRelatedToProgramming_Other        noFeedback
# 18  positiveTone       relatedToProgramming_relatedToTask        noFeedback
# 19  positiveTone  notRelatedToProgramming_relativeToRoles        noFeedback
# 20  positiveTone            notRelatedToProgramming_Other  responseValidity
# 21  positiveTone  notRelatedToProgramming_relativeToRoles        noFeedback
# 22  positiveTone       relatedToProgramming_relatedToTask            errors
# 23  positiveTone       relatedToProgramming_relatedToTask            errors
# 24  positiveTone            notRelatedToProgramming_Other        noFeedback

# %% [markdown]
# ## Classification sur le coprus pour calcul du kappa

# %%
df = pd.read_csv("SousCorpusMessages.csv")
# Ensure that the message num is an integer for sorting
df['messageID'] = df['messageID'].astype(int) 
df['groupID'] = df['groupID'].astype(int) 
df['seanceID'] = df['seanceID'].astype(int)  

# Group the dataframe by conversation
grouped = df.groupby(['seanceID','groupID'])

# We'll save the conversations as an array of dictionaries were every conversation is an entry
conversations_dict = []
# For every conversation in the dataframe
for activity_id, group in grouped:
    # Convert the utterances into a list of dictionaries, then sort entries by message num
    conversation_text = group.sort_values('messageID').apply(
        lambda row: {"messageID": row['messageID'], "role": row['role'], "message": row['message']},
        axis=1
    ).tolist()
    
    # Create a conversation
    conversation = {
        "seance_ID": activity_id[0],
        "groupe_ID": activity_id[1],
        "conversation": conversation_text
    }
    # Append the conversations as a dictionary
    conversations_dict.append(conversation)

# This is not a JSON, it will be important later
conversations_dict[0]
# Out:
# {'seance_ID': 1,
#  'groupe_ID': 4,
#  'conversation': [{'messageID': 24,
#    'role': 'Driver',
#    'message': 'tu pense si je fais un for in in range avec un for j in range dedans �a peut marcher? ',
#    'fileId': '1db9dee2-2702-457f-aa07-6b60589446ce'},
#   {'messageID': 30,
#    'role': 'Navigator',
#    'message': 'en vrai c\'est pas mieux de faire un "if len(a) != len(b)"',
#    'fileId': '1db9dee2-2702-457f-aa07-6b60589446ce'},
#   {'messageID': 34,
#    'role': 'Navigator',
#    'message': "quand je teste le code il me disent y'a des erreurs de type",
#    'fileId': '1db9dee2-2702-457f-aa07-6b60589446ce'}]}

# %%
len(conversations_dict)
# Out:
# 102

# %%
prompt_system, prompt_user, prompt_agent = read_prompts(PROMPT_FOLDER_OPENAI)
classified = classify_conversation(openai_client,
                                    prompt_system,
                                    prompt_user,
                                    prompt_agent,
                                    conversations_dict[:5])
# Out:
# Classifying...:   0%|          | 0/5 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[175], line 2
#       1 prompt_system, prompt_user, prompt_agent = read_prompts(PROMPT_FOLDER)
# ----> 2 classified = classify_conversation(openai_client,
#       3                                   prompt_system,
#       4                                      prompt_user,
#       5                                      prompt_agent,
#       6                                      conversations_dict[:5])
#
# Cell In[169], line 136, in classify_conversation(openai_client, prompt_system, prompt_user, prompt_agent, conversations)
#     134 out = []
#     135 for conversation in tqdm(conversations, desc='Classifying...'):
# --> 136     response = classify_sentences(openai_client,
#     137                                   str(conversation),
#     138                                   prompt_system,
#     139                                   prompt_user,
#     140                                   prompt_agent)
#     141     out.append(response)
#     142 return out
#
# Cell In[169], line 85, in classify_sentences(client, message, prompt_system, prompt_user, prompt_agent)
#      54 '''
#      55 Classifies a given message using an OpenAI model with predefined prompts.
#      56
#    (...)
#      70     None: If an error occurs during the classification process.
#      71 '''
#      72 # Docs: https://platform.openai.com/docs/api-reference/chat/create
#      73 # It is possible to thinker with different parameters such as  response_format, seed,
#      74 # frequency_penalty and so on, but in this case we specified:
#    (...)
#      83 # Stream: Set to False, to only recieve the entire response message, to avoid processing the stream after
#      84 # Timeout: Set to 25 minutes, because conversations can take a lot of time to process.
# ---> 85 response = client.chat.completions.create(
#      86     model="gpt-4o-mini",
#      87     messages=[
#      88         {"role": "system", "content": prompt_system},
#      89         {"role": "user", "content": prompt_user},
#      90         {"role": "assistant", "content": prompt_agent},
#      91         {"role": "user", "content": message}
#      92     ],
#      93     temperature=0,
#      94     stream=False,
#      95     timeout=1500  # Set the timeout to 1500 seconds
#      96 )
#      98 # Capture errors
#      99 try:
#     100     # If not error, we get the response
#
# File c:\Users\cbd65\anaconda3\envs\jupyterenv\lib\site-packages\openai\_utils\_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File c:\Users\cbd65\anaconda3\envs\jupyterenv\lib\site-packages\openai\resources\chat\completions\completions.py:879, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     837 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     838 def create(
#     839     self,
#    (...)
#     876     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     877 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     878     validate_response_format(response_format)
# --> 879     return self._post(
#     880         "/chat/completions",
#     881         body=maybe_transform(
#     882             {
#     883                 "messages": messages,
#     884                 "model": model,
#     885                 "audio": audio,
#     886                 "frequency_penalty": frequency_penalty,
#     887                 "function_call": function_call,
#     888                 "functions": functions,
#     889                 "logit_bias": logit_bias,
#     890                 "logprobs": logprobs,
#     891                 "max_completion_tokens": max_completion_tokens,
#     892                 "max_tokens": max_tokens,
#     893                 "metadata": metadata,
#     894                 "modalities": modalities,
#     895                 "n": n,
#     896                 "parallel_tool_calls": parallel_tool_calls,
#     897                 "prediction": prediction,
#     898                 "presence_penalty": presence_penalty,
#     899                 "reasoning_effort": reasoning_effort,
#     900                 "response_format": response_format,
#     901                 "seed": seed,
#     902                 "service_tier": service_tier,
#     903                 "stop": stop,
#     904                 "store": store,
#     905                 "stream": stream,
#     906                 "stream_options": stream_options,
#     907                 "temperature": temperature,
#     908                 "tool_choice": tool_choice,
#     909                 "tools": tools,
#     910                 "top_logprobs": top_logprobs,
#     911                 "top_p": top_p,
#     912                 "user": user,
#     913             },
#     914             completion_create_params.CompletionCreateParams,
#     915         ),
#     916         options=make_request_options(
#     917             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     918         ),
#     919         cast_to=ChatCompletion,
#     920         stream=stream or False,
#     921         stream_cls=Stream[ChatCompletionChunk],
#     922     )
#
# File c:\Users\cbd65\anaconda3\envs\jupyterenv\lib\site-packages\openai\_base_client.py:1290, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1276 def post(
#    1277     self,
#    1278     path: str,
#    (...)
#    1285     stream_cls: type[_StreamT] | None = None,
#    1286 ) -> ResponseT | _StreamT:
#    1287     opts = FinalRequestOptions.construct(
#    1288         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1289     )
# -> 1290     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\cbd65\anaconda3\envs\jupyterenv\lib\site-packages\openai\_base_client.py:967, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     964 else:
#     965     retries_taken = 0
# --> 967 return self._request(
#     968     cast_to=cast_to,
#     969     options=options,
#     970     stream=stream,
#     971     stream_cls=stream_cls,
#     972     retries_taken=retries_taken,
#     973 )
#
# File c:\Users\cbd65\anaconda3\envs\jupyterenv\lib\site-packages\openai\_base_client.py:1056, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1054 if remaining_retries > 0 and self._should_retry(err.response):
#    1055     err.response.close()
# -> 1056     return self._retry_request(
#    1057         input_options,
#    1058         cast_to,
#    1059         retries_taken=retries_taken,
#    1060         response_headers=err.response.headers,
#    1061         stream=stream,
#    1062         stream_cls=stream_cls,
#    1063     )
#    1065 # If the response is streamed then we need to explicitly read the response
#    1066 # to completion before attempting to access the response text.
#    1067 if not err.response.is_closed:
#
# File c:\Users\cbd65\anaconda3\envs\jupyterenv\lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1101 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1102 # different thread if necessary.
#    1103 time.sleep(timeout)
# -> 1105 return self._request(
#    1106     options=options,
#    1107     cast_to=cast_to,
#    1108     retries_taken=retries_taken + 1,
#    1109     stream=stream,
#    1110     stream_cls=stream_cls,
#    1111 )
#
# File c:\Users\cbd65\anaconda3\envs\jupyterenv\lib\site-packages\openai\_base_client.py:1056, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1054 if remaining_retries > 0 and self._should_retry(err.response):
#    1055     err.response.close()
# -> 1056     return self._retry_request(
#    1057         input_options,
#    1058         cast_to,
#    1059         retries_taken=retries_taken,
#    1060         response_headers=err.response.headers,
#    1061         stream=stream,
#    1062         stream_cls=stream_cls,
#    1063     )
#    1065 # If the response is streamed then we need to explicitly read the response
#    1066 # to completion before attempting to access the response text.
#    1067 if not err.response.is_closed:
#
# File c:\Users\cbd65\anaconda3\envs\jupyterenv\lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1101 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1102 # different thread if necessary.
#    1103 time.sleep(timeout)
# -> 1105 return self._request(
#    1106     options=options,
#    1107     cast_to=cast_to,
#    1108     retries_taken=retries_taken + 1,
#    1109     stream=stream,
#    1110     stream_cls=stream_cls,
#    1111 )
#
# File c:\Users\cbd65\anaconda3\envs\jupyterenv\lib\site-packages\openai\_base_client.py:1071, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1068         err.response.read()
#    1070     log.debug("Re-raising status error")
# -> 1071     raise self._make_status_error_from_response(err.response) from None
#    1073 return self._process_response(
#    1074     cast_to=cast_to,
#    1075     options=options,
#    (...)
#    1079     retries_taken=retries_taken,
#    1080 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-Hb86CiMZyMYd9WwCXvjB4As5 on tokens per min (TPM): Limit 100000, Used 100000, Requested 1772. Please try again in 12h45m30.24s. Visit https://platform.openai.com/account/rate-limits to learn more. You can increase your rate limit by adding a payment method to your account at https://platform.openai.com/account/billing.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}

# %%
classified
# Out:
# ['{\n  "seance_ID": 1,\n  "groupe_ID": 4,\n  "conversation": [\n    {\n      "messageID": 24,\n      "role": "Driver",\n      "message": "tu pense si je fais un for in in range avec un for j in range dedans ça peut marcher? ",\n      "form": {\n        "annotation": "question"\n      },\n      "tone": {\n        "annotation": "positiveTone"\n      },\n      "content": {\n        "annotation": "relatedToProgramming_relatedToTask"\n      },\n      "nature": {\n        "annotation": "howToProceed"\n      }\n    },\n    {\n      "messageID": 30,\n      "role": "Navigator",\n      "message": "en vrai c\'est pas mieux de faire un \\"if len(a) != len(b)\\"",\n      "form": {\n        "annotation": "question"\n      },\n      "tone": {\n        "annotation": "positiveTone"\n      },\n      "content": {\n        "annotation": "relatedToProgramming_relatedToTask"\n      },\n      "nature": {\n        "annotation": "howToProceed"\n      }\n    },\n    {\n      "messageID": 34,\n      "role": "Navigator",\n      "message": "quand je teste le code il me disent y\'a des erreurs de type",\n      "form": {\n        "annotation": "positiveSentence"\n      },\n      "tone": {\n        "annotation": "positiveTone"\n      },\n      "content": {\n        "annotation": "relatedToProgramming_relatedToTask"\n      },\n      "nature": {\n        "annotation": "errors"\n      }\n    }\n  ]\n}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 7,\n  "conversation": [\n    {\n      "messageID": 56,\n      "role": "Navigator",\n      "message": "def coincide(tableau1, tableau2):     # On s\'assure que les deux tableaux ont la même longueur     if len(tableau1) != len(tableau2):         return []      # On crée un tableau vide pour stocker les indices où les éléments sont identiques     result = []          # On parcourt les deux tableaux et on compare les éléments     for i in range(len(tableau1)):         if tableau1[i] == tableau2[i]:             result.append(i)      return result  # Exemples d\'utilisation : print(coincide([78, 23, 12, 12, 54, 32], [67, 23, 44, 12, 54, 32]))  # [1, 3, 4, 5] print(coincide([\\"antoine\\", \\"isaac\\", \\"denis\\"], [\\"jeanne\\", \\"sofiane\\", \\"lise\\"]))  # []",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "correctResponse"\n      }\n    },\n    {\n      "messageID": 73,\n      "role": "Navigator",\n      "message": "ta pas besoin du return  []",\n      "annotation": {\n        "form": "negativeSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "errors"\n      }\n    },\n    {\n      "messageID": 75,\n      "role": "Navigator",\n      "message": "c\'est ok ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "responseValidity"\n      }\n    }\n  ]\n}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 9,\n  "conversation": [\n    {\n      "messageID": 82,\n      "role": "Navigator",\n      "message": "et la ta compris un peu le contexte ? ",\n      "form": "question",\n      "tone": "positiveTone",\n      "content": "notRelatedToProgramming_Other",\n      "nature": "askingForHelp"\n    },\n    {\n      "messageID": 83,\n      "role": "Driver",\n      "message": "je sais qu\'\'il faut impl�menter le tableau pour l\'utiliser dans la fonction coincide",\n      "form": "positiveSentence",\n      "tone": "positiveTone",\n      "content": "relatedToProgramming_relatedToTask",\n      "nature": "taskKnowledge"\n    }\n  ]\n}',
#  '{\'seance_ID\': 1,\n \'groupe_ID\': 16,\n \'conversation\': [{\'messageID\': 134,\n   \'role\': \'Driver\',\n   \'message\': "j\'essaye encore",\n   \'form\': {\'annotation\': \'positiveSentence\'},\n   \'tone\': {\'annotation\': \'positiveTone\'},\n   \'content\': {\'annotation\': \'notRelatedToProgramming_Other\'},\n   \'nature\': {\'annotation\': \'motivationnalFeedback\'}}]}',
#  "{'seance_ID': 1,\n 'groupe_ID': 25,\n 'conversation': [{'messageID': 161,\n   'role': 'Navigator',\n   'message': 'Utilise append pour ajouter un �l�ment dans une liste',\n   'form': 'imperativeSentence',\n   'tone': 'positiveTone',\n   'content': 'relatedToProgramming_relatedToTask',\n   'nature': 'correctResponse'}]}",
#  '{\'seance_ID\': 1,\n \'groupe_ID\': 27,\n \'conversation\': [{\'messageID\': 175,\n   \'role\': \'Navigator\',\n   \'message\': \'commence gros ou laisse moi la main\',\n   \'form\': {\'annotation\': \'imperativeSentence\'},\n   \'tone\': {\'annotation\': \'positiveTone\'},\n   \'content\': {\'annotation\': \'notRelatedToProgramming_relativeToRoles\'},\n   \'nature\': {\'annotation\': \'howToProceed\'}},\n  {\'messageID\': 179,\n   \'role\': \'Navigator\',\n   \'message\': "mais il faut que l\'on parcours les deux tableaux ",\n   \'form\': {\'annotation\': \'positiveSentence\'},\n   \'tone\': {\'annotation\': \'positiveTone\'},\n   \'content\': {\'annotation\': \'relatedToProgramming_relatedToTask\'},\n   \'nature\': {\'annotation\': \'taskKnowledge\'}},\n  {\'messageID\': 180,\n   \'role\': \'Navigator\',\n   \'message\': \'et tu as raison pour le tableau vide\',\n   \'form\': {\'annotation\': \'positiveSentence\'},\n   \'tone\': {\'annotation\': \'positiveTone\'},\n   \'content\': {\'annotation\': \'relatedToProgramming_relatedToTask\'},\n   \'nature\': {\'annotation\': \'responseValidity\'}},\n  {\'messageID\': 203,\n   \'role\': \'Navigator\',\n   \'message\': "il faudrait que \'on prenne l\'indice",\n   \'form\': {\'annotation\': \'positiveSentence\'},\n   \'tone\': {\'annotation\': \'positiveTone\'},\n   \'content\': {\'annotation\': \'relatedToProgramming_relatedToTask\'},\n   \'nature\': {\'annotation\': \'howToProceed\'}},\n  {\'messageID\': 205,\n   \'role\': \'Navigator\',\n   \'message\': "et qu\'il soit mis dans egal",\n   \'form\': {\'annotation\': \'positiveSentence\'},\n   \'tone\': {\'annotation\': \'positiveTone\'},\n   \'content\': {\'annotation\': \'relatedToProgramming_relatedToTask\'},\n   \'nature\': {\'annotation\': \'howToProceed\'}}]}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 29,\n  "conversation": [\n    {\n      "messageID": 244,\n      "role": "Driver",\n      "message": "le True et le False c\'est pour dire que ils sont égaux ?",\n      "form": "question",\n      "tone": "positiveTone",\n      "content": "relatedToProgramming_relatedToTask",\n      "nature": "askingForHelp"\n    },\n    {\n      "messageID": 245,\n      "role": "Driver",\n      "message": "si ils sont egaux ou pas",\n      "form": "question",\n      "tone": "positiveTone",\n      "content": "relatedToProgramming_relatedToTask",\n      "nature": "askingForHelp"\n    },\n    {\n      "messageID": 246,\n      "role": "Navigator",\n      "message": "Non c\'est la réponse qu\'il va renvoyer, True ils sont les même nombre d\'éléments, False : il n\'ont pas le même nombre",\n      "form": "positiveSentence",\n      "tone": "positiveTone",\n      "content": "relatedToProgramming_relatedToTask",\n      "nature": "responseValidity"\n    }\n  ]\n}',
#  '{\'seance_ID\': 1,\n \'groupe_ID\': 30,\n \'conversation\': [\n  {\'messageID\': 262, \'role\': \'Navigator\', \'message\': \'faut mettre la longueur du tableau noramlement \',\n   \'form\': {\'annotation\': \'positiveSentence\'},\n   \'tone\': {\'annotation\': \'positiveTone\'},\n   \'content\': {\'annotation\': \'relatedToProgramming_relatedToTask\'},\n   \'nature\': {\'annotation\': \'howToProceed\'}},\n  {\'messageID\': 264, \'role\': \'Navigator\', \'message\': "oui je pense mais il y\'a aussi le truc de la position",\n   \'form\': {\'annotation\': \'positiveSentence\'},\n   \'tone\': {\'annotation\': \'positiveTone\'},\n   \'content\': {\'annotation\': \'relatedToProgramming_relatedToTask\'},\n   \'nature\': {\'annotation\': \'howToProceed\'}},\n  {\'messageID\': 267, \'role\': \'Navigator\', \'message\': "il faut mettre le (i) a coter d\'append",\n   \'form\': {\'annotation\': \'positiveSentence\'},\n   \'tone\': {\'annotation\': \'positiveTone\'},\n   \'content\': {\'annotation\': \'relatedToProgramming_relatedToTask\'},\n   \'nature\': {\'annotation\': \'howToProceed\'}}\n]}']

# %%
out_df = convert_to_dataframe(classified, [LABEL_COLUMN_1,LABEL_COLUMN_2,LABEL_COLUMN_3,LABEL_COLUMN_4])
out_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[162], line 1
# ----> 1 out_df = convert_to_dataframe(classified, [LABEL_COLUMN_1,LABEL_COLUMN_2,LABEL_COLUMN_3,LABEL_COLUMN_4])
#       2 out_df
#
# Cell In[106], line 61, in convert_to_dataframe(list_of_json, label_columns)
#      52     # For every utterance in the conversation
#      53     for message in json_entry['conversation']:
#      54         # Create an entry (row) to use then in the dataframe
#      55         flattened_data.append({
#      56             'seance_ID' : seance_id,
#      57             'groupe_ID': groupe_id,
#      58             'messageID': message['messageID'],
#      59             'role': message['role'],
#      60             'message': message['message'],
# ---> 61             label_columns[0] : message['annotation']['form'],    #ajouter ici les autres attributs
#      62             label_columns[1] : message['annotation']['tone'],
#      63             label_columns[2] : message['annotation']['content'],
#      64             label_columns[3] : message['annotation']['nature']
#      65         })
#      67 # Convert the entries in a dataframe
#      68 out_df = pd.DataFrame(flattened_data)
#
# KeyError: 'annotation'

# %%
classified2 = classify_conversation(openai_client,
                                  prompt_system,
                                     prompt_user,
                                     prompt_agent,
                                     conversations_dict[8:])
# Out:
# Classifying...: 100%|██████████| 12/12 [03:18<00:00, 16.52s/it]

# %%
out_df2 = convert_to_dataframe(classified2, [LABEL_COLUMN_1,LABEL_COLUMN_2,LABEL_COLUMN_3,LABEL_COLUMN_4])
out_df2

# %% [markdown]
# ## Classifications avec prompt en français

# %%
prompt_system, prompt_user, prompt_agent = read_prompts(PROMPT_FOLDER_MISTRAL) #Prompts en français
classified = classify_conversation(openai_client,
                                    prompt_system,
                                    prompt_user,
                                    prompt_agent,
                                    conversations_dict[:5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 prompt_system, prompt_user, prompt_agent = read_prompts(PROMPT_FOLDER_MISTRAL) #Prompts en français
# ----> 2 classified = classify_conversation(openai_client,
#       3                                     prompt_system,
#       4                                     prompt_user,
#       5                                     prompt_agent,
#       6                                     conversations_dict[:5])
#
# NameError: name 'openai_client' is not defined

# %%
out_df = convert_to_dataframe(classified, [LABEL_COLUMN_1,LABEL_COLUMN_2,LABEL_COLUMN_3,LABEL_COLUMN_4])
out_df
# Out:
#       seance_ID    groupe_ID       role  messageID  utterance_num  \
# 0   np.int64(1)  np.int64(0)  Navigator          0              0
# 1   np.int64(1)  np.int64(0)  Navigator          1              0
# 2   np.int64(1)  np.int64(1)     Driver          2              0
# 3   np.int64(1)  np.int64(1)     Driver          3              0
# 4   np.int64(1)  np.int64(1)  Navigator          4              0
# 5   np.int64(1)  np.int64(1)  Navigator          5              0
# 6   np.int64(1)  np.int64(1)  Navigator          6              0
# 7   np.int64(1)  np.int64(1)  Navigator          7              0
# 8   np.int64(1)  np.int64(1)  Navigator          8              0
# 9   np.int64(1)  np.int64(1)  Navigator          9              0
# 10  np.int64(1)  np.int64(1)  Navigator         10              0
# 11  np.int64(1)  np.int64(1)  Navigator         11              0
# 12  np.int64(1)  np.int64(1)  Navigator         12              0
# 13  np.int64(1)  np.int64(2)     Driver         13              0
# 14  np.int64(1)  np.int64(2)     Driver         14              0
# 15  np.int64(1)  np.int64(3)     Driver         15              0
# 16  np.int64(1)  np.int64(3)  Navigator         16              0
# 17  np.int64(1)  np.int64(3)     Driver         17              0
# 18  np.int64(1)  np.int64(3)  Navigator         18              0
# 19  np.int64(1)  np.int64(3)     Driver         19              0
# 20  np.int64(1)  np.int64(3)  Navigator         20              0
# 21  np.int64(1)  np.int64(3)  Navigator         21              0
# 22  np.int64(1)  np.int64(4)     Driver         22              0
# 23  np.int64(1)  np.int64(4)  Navigator         23              0
# 24  np.int64(1)  np.int64(4)     Driver         24              0
# 25  np.int64(1)  np.int64(4)  Navigator         25              0
# 26  np.int64(1)  np.int64(4)     Driver         26              0
# 27  np.int64(1)  np.int64(4)  Navigator         27              0
# 28  np.int64(1)  np.int64(4)     Driver         28              0
# 29  np.int64(1)  np.int64(4)  Navigator         29              0
# 30  np.int64(1)  np.int64(4)  Navigator         30              0
# 31  np.int64(1)  np.int64(4)     Driver         31              0
# 32  np.int64(1)  np.int64(4)     Driver         32              0
# 33  np.int64(1)  np.int64(4)  Navigator         33              0
# 34  np.int64(1)  np.int64(4)  Navigator         34              0
# 35  np.int64(1)  np.int64(4)  Navigator         35              0
# 36  np.int64(1)  np.int64(4)  Navigator         36              0
# 37  np.int64(1)  np.int64(4)     Driver         37              0
# 38  np.int64(1)  np.int64(4)  Navigator         38              0
# 39  np.int64(1)  np.int64(4)     Driver         39              0
# 40  np.int64(1)  np.int64(4)     Driver         40              0
# 41  np.int64(1)  np.int64(4)  Navigator         41              0
# 42  np.int64(1)  np.int64(4)     Driver         42              0
# 43  np.int64(1)  np.int64(4)     Driver         43              0
# 44  np.int64(1)  np.int64(4)  Navigator         44              0
# 45  np.int64(1)  np.int64(4)  Navigator         45              0
# 46  np.int64(1)  np.int64(4)  Navigator         46              0
#
#                                               message  \
# 0                                         Tu es qui ,
# 1                            On se met 5 partout ok ?
# 2                                                 Opé
# 3                                            Opé lmkt
# 4                                   A PAR SA LE COUZ
# 5                                                Opé
# 6                                      Ou lé jolie ?
# 7                                               A ou
# 8                                           Commencé
# 9                                 Comment nous fé la
# 10                               c'est kwé faut fait
# 11                          Lève ton main un coup la
# 12                           aide a moins un coup la
# 13                                               roro
# 14                                         Qui est là
# 15           je ne sais pas comment voir le résultat
# 16                        faut mettre print(coincide)
# 17                                             essaye
# 18                                             attend
# 19                             je crois que c'est bon
# 20                                             attend
# 21                                             attend
# 22                                            Bonjour
# 23                                            Bonjour
# 24  tu pense si je fais un for in in range avec un...
# 25                                               oui
# 26                                    tu veux editer?
# 27                                      comme tu veux
# 28               je teste si ça marche pas on echange
# 29                                               vsy
# 30  en vrai c'est pas mieux de faire un "if len(a)...
# 31                                     tu veux teste?
# 32                                  demande l'édition
# 33                               vsy je teste le code
# 34  quand je teste le code il me disent y'a des er...
# 35                                           pour int
# 36                                     je sais pas pk
# 37  demande a éditer je te passe la main tu teste ...
# 38  vsy je sauvegarde juste le ocde que t'a déja fait
# 39                                                 ok
# 40                                        je supprime
# 41                                 c bon t'as la main
# 42               je crois c'est bon , je suis pas sur
# 43                                    tu peux tester?
# 44  il y a des erreurs sur plusieurs lignes mais l...
# 45                            sur le return positions
# 46                         on fini l'activité ducoup?
#
#                             forme           ton  \
# 0                        question  positiveTone
# 1                        question  positiveTone
# 2                positiveSentence  positiveTone
# 3                positiveSentence  positiveTone
# 4                positiveSentence  positiveTone
# 5                positiveSentence  positiveTone
# 6                        question  positiveTone
# 7                positiveSentence  positiveTone
# 8                positiveSentence  positiveTone
# 9                        question  positiveTone
# 10               positiveSentence  positiveTone
# 11             imperativeSentence  positiveTone
# 12             imperativeSentence  positiveTone
# 13  notRelatedToProgramming_Other  positiveTone
# 14                       question  positiveTone
# 15               negativeSentence  positiveTone
# 16             imperativeSentence  positiveTone
# 17               positiveSentence  positiveTone
# 18             imperativeSentence  positiveTone
# 19               positiveSentence  positiveTone
# 20             imperativeSentence  positiveTone
# 21             imperativeSentence  positiveTone
# 22               positiveSentence  positiveTone
# 23               positiveSentence  positiveTone
# 24                       question  positiveTone
# 25               positiveSentence  positiveTone
# 26                       question  positiveTone
# 27               positiveSentence  positiveTone
# 28               positiveSentence  positiveTone
# 29               positiveSentence  positiveTone
# 30               positiveSentence  positiveTone
# 31                       question  positiveTone
# 32             imperativeSentence  positiveTone
# 33               positiveSentence  positiveTone
# 34               positiveSentence  positiveTone
# 35  notRelatedToProgramming_Other  positiveTone
# 36               positiveSentence  positiveTone
# 37             imperativeSentence  positiveTone
# 38               positiveSentence  positiveTone
# 39               positiveSentence  positiveTone
# 40               positiveSentence  positiveTone
# 41               positiveSentence  positiveTone
# 42               positiveSentence  positiveTone
# 43                       question  positiveTone
# 44               positiveSentence  positiveTone
# 45  notRelatedToProgramming_Other  positiveTone
# 46                       question  positiveTone
#
#                                content                 nature
# 0        notRelatedToProgramming_Other             noFeedback
# 1        notRelatedToProgramming_Other             noFeedback
# 2        notRelatedToProgramming_Other             noFeedback
# 3        notRelatedToProgramming_Other             noFeedback
# 4        notRelatedToProgramming_Other             noFeedback
# 5        notRelatedToProgramming_Other             noFeedback
# 6        notRelatedToProgramming_Other             noFeedback
# 7        notRelatedToProgramming_Other             noFeedback
# 8        notRelatedToProgramming_Other             noFeedback
# 9        notRelatedToProgramming_Other             noFeedback
# 10       notRelatedToProgramming_Other             noFeedback
# 11       notRelatedToProgramming_Other             noFeedback
# 12       notRelatedToProgramming_Other             noFeedback
# 13       notRelatedToProgramming_Other             noFeedback
# 14       notRelatedToProgramming_Other             noFeedback
# 15       notRelatedToProgramming_Other             noFeedback
# 16  relatedToProgramming_relatedToTask        correctResponse
# 17       notRelatedToProgramming_Other  motivationnalFeedback
# 18       notRelatedToProgramming_Other             noFeedback
# 19       notRelatedToProgramming_Other       responseValidity
# 20       notRelatedToProgramming_Other             noFeedback
# 21       notRelatedToProgramming_Other             noFeedback
# 22       notRelatedToProgramming_Other             noFeedback
# 23       notRelatedToProgramming_Other             noFeedback
# 24  relatedToProgramming_relatedToTask             noFeedback
# 25       notRelatedToProgramming_Other             noFeedback
# 26       notRelatedToProgramming_Other             noFeedback
# 27       notRelatedToProgramming_Other             noFeedback
# 28       notRelatedToProgramming_Other             noFeedback
# 29       notRelatedToProgramming_Other             noFeedback
# 30  relatedToProgramming_relatedToTask             noFeedback
# 31       notRelatedToProgramming_Other             noFeedback
# 32       notRelatedToProgramming_Other             noFeedback
# 33  relatedToProgramming_relatedToTask             noFeedback
# 34  relatedToProgramming_relatedToTask                 errors
# 35       notRelatedToProgramming_Other             noFeedback
# 36       notRelatedToProgramming_Other          askingForHelp
# 37       notRelatedToProgramming_Other             noFeedback
# 38  relatedToProgramming_relatedToTask             noFeedback
# 39       notRelatedToProgramming_Other             noFeedback
# 40  relatedToProgramming_relatedToTask             noFeedback
# 41       notRelatedToProgramming_Other             noFeedback
# 42        noRelatedToProgramming_Other       responseValidity
# 43       notRelatedToProgramming_Other             noFeedback
# 44  relatedToProgramming_relatedToTask                 errors
# 45  relatedToProgramming_relatedToTask                 errors
# 46       notRelatedToProgramming_Other             noFeedback

# %%
out_df.to_csv("annotation_openai_conv_0_to_5_french_prompt.csv")

# %% [markdown]
# # Classification automatique : API Mistral AI

# %% [markdown]
# ## Instanciation du modèle

# %%
#! pip install mistralai

# %%
f = open("keys.txt")
key = f.readline().strip('\n')
f.close()
#key = key[12:]

# %%
api_key = key
model = "open-mistral-nemo"

client = Mistral(api_key=api_key)

# %% [markdown]
# ## Fonctions de classification

# %%
def classify_sentences_mistral(client: Mistral, 
                        message: str,
                        prompt_system: str,
                        prompt_user: str,
                        prompt_agent: str):
    
    '''
    Classifies a given message using a Mistral model with predefined prompts.

    This function sends a message to the Mistral API along with system, user, and agent prompts
    to generate a classification response. It handles errors by logging them and returning `None`
    if the classification fails.

    Args:
        client (Mistral): An instance of the Mistral client used to interact with the API.
        message (str): The message to be classified.
        prompt_system (str): The system prompt to guide the model's behavior.
        prompt_user (str): The user prompt to provide context or instructions.
        prompt_agent (str): The agent prompt to simulate the assistant's role.

    Returns:
        str: The content of the model's response if the classification is successful.
        None: If an error occurs during the classification process.
    '''
    
    prompt = prompt_system + "\n Un exemple d'entrée est :\n" + prompt_user +"\n et un exemple de sortie est :\n"+ prompt_agent+".\n Les messages que tu dois annoter sont :\n " +message
    #print(prompt)
    

    response = client.chat.complete(
        model="open-mistral-nemo",
        messages=[
            {"role": "user", "content": prompt}
        ],
        temperature=0,
        stream=False,
        response_format = {
            "type": "json_object",
        }
    )


    # Capture errors
    try:
        # If not error, we get the response
        return response.choices[0].message.content
    except:
        # If error, the function returns None, but the error message is appended
        # to a global array
        errors.append({'message': message, 'response': response})
        return None


def classify_conversation_mistral(mistral_client: Mistral,
                        prompt_system: str,
                        prompt_user: str,
                        prompt_agent: str,
                        conversations: list):
    '''
    Classifies a list of conversations using an OpenAI model with predefined prompts.

    This function iterates over a list of conversations, classifies each one using the
    `classify_sentences` function, and collects the results. A progress bar is displayed
    to track the classification process.

    Args:
        openai_client (OpenAI): An instance of the OpenAI client used to interact with the API.
        prompt_system (str): The system prompt to guide the model's behavior.
        prompt_user (str): The user prompt to provide context or instructions.
        prompt_agent (str): The agent prompt to simulate the assistant's role.
        conversations (list): A list of conversations (strings) to be classified.

    Returns:
        list: A list of classification results corresponding to each conversation. Each result
                is the output of the `classify_sentences` function, which may be a string or `None`
                if an error occurred during classification.
    '''

    out = []
    for conversation in tqdm(conversations, desc='Classifying...'):     
        response = classify_sentences_mistral(mistral_client, 
                                        str(conversation), 
                                        prompt_system, 
                                        prompt_user, 
                                        prompt_agent)

        out.append(response)
    return out

# %% [markdown]
# ## Classification

# %%
conversations_dict[0]
# Out:
# {'seance_ID': 1,
#  'groupe_ID': 0,
#  'conversation': [{'messageID': 0,
#    'role': 'Navigator',
#    'message': 'Tu es qui ,'},
#   {'messageID': 1,
#    'role': 'Navigator',
#    'message': 'On se met 5 partout ok ?'}]}

# %%
client = Mistral(api_key=api_key)
prompt_system, prompt_user, prompt_agent = read_prompts(PROMPT_FOLDER_MISTRAL)
labeled_data = classify_conversation_mistral(client,
                                    prompt_system,
                                    prompt_user,
                                    prompt_agent,
                                    conversations_dict[:5])
# Out:
# Classifying...: 100%|██████████| 5/5 [00:25<00:00,  5.18s/it]

# %%
labeled_data
# Out:
# ['{"seance_ID": 1, "groupe_ID": 0, "conversation": [{"messageID": 0, "role": "Navigator", "message": "Tu es qui ,", "annotation": {"form": "question", "tone": "positiveTone", "content": "notRelatedToProgramming_Other", "nature": "noFeedback"}}, {"messageID": 1, "role": "Navigator", "message": "On se met 5 partout ok ?", "annotation": {"form": "imperativeSentence", "tone": "positiveTone", "content": "notRelatedToProgramming_Other", "nature": "noFeedback"}}]}',
#  '{"seance_ID": 1, "groupe_ID": 1, "conversation": [{"messageID": 2, "role": "Driver", "message": "Opé", "annotation": {"form": "positiveSentence", "tone": "positiveTone", "content": "notRelatedToProgramming_Other", "nature": "noFeedback"}}, {"messageID": 3, "role": "Driver", "message": "Opé lmkt", "annotation": {"form": "positiveSentence", "tone": "positiveTone", "content": "notRelatedToProgramming_Other", "nature": "noFeedback"}}, {"messageID": 4, "role": "Navigator", "message": "A PAR SA LE COUZ ", "annotation": {"form": "positiveSentence", "tone": "positiveTone", "content": "notRelatedToProgramming_Other", "nature": "noFeedback"}}, {"messageID": 5, "role": "Navigator", "message": "Opé ", "annotation": {"form": "positiveSentence", "tone": "positiveTone", "content": "notRelatedToProgramming_Other", "nature": "noFeedback"}}, {"messageID": 6, "role": "Navigator", "message": "Ou lé jolie ? ", "annotation": {"form": "question", "tone": "positiveTone", "content": "notRelatedToProgramming_Other", "nature": "noFeedback"}}, {"messageID": 7, "role": "Navigator", "message": "A ou ", "annotation": {"form": "positiveSentence", "tone": "positiveTone", "content": "notRelatedToProgramming_Other", "nature": "noFeedback"}}, {"messageID": 8, "role": "Navigator", "message": "Commencé ", "annotation": {"form": "positiveSentence", "tone": "positiveTone", "content": "notRelatedToProgramming_Other", "nature": "noFeedback"}}, {"messageID": 9, "role": "Navigator", "message": "Comment nous fé la ", "annotation": {"form": "question", "tone": "positiveTone", "content": "notRelatedToProgramming_Other", "nature": "noFeedback"}}, {"messageID": 10, "role": "Navigator", "message": "c\'est kwé faut fait ", "annotation": {"form": "positiveSentence", "tone": "positiveTone", "content": "notRelatedToProgramming_Other", "nature": "noFeedback"}}, {"messageID": 11, "role": "Navigator", "message": "Lève ton main un coup la ", "annotation": {"form": "imperativeSentence", "tone": "positiveTone", "content": "notRelatedToProgramming_Other", "nature": "noFeedback"}}, {"messageID": 12, "role": "Navigator", "message": "aide a moins un coup la ", "annotation": {"form": "positiveSentence", "tone": "positiveTone", "content": "notRelatedToProgramming_Other", "nature": "noFeedback"}}]}',
#  '{"seance_ID": 1, "groupe_ID": 2, "conversation": [{"messageID": 13, "role": "Driver", "message": "roro", "annotation": {"form": "positiveSentence", "tone": "positiveTone", "content": "notRelatedToProgramming_Other", "nature": "noFeedback"}}, {"messageID": 14, "role": "Driver", "message": "Qui est là", "annotation": {"form": "question", "tone": "positiveTone", "content": "notRelatedToProgramming_Other", "nature": "askingForHelp"}}]}',
#  '{"seance_ID": 1, "groupe_ID": 3, "conversation": [{"messageID": 15, "role": "Driver", "message": "je ne sais pas comment voir le résultat ", "annotation": {"form": "negativeSentence", "tone": "positiveTone", "content": "relatedToProgramming_notRelatedToTask", "nature": "askingForHelp"}}, {"messageID": 16, "role": "Navigator", "message": "faut mettre print(coincide)", "annotation": {"form": "positiveSentence", "tone": "positiveTone", "content": "relatedToProgramming_relatedToTask", "nature": "taskKnowledge"}}, {"messageID": 17, "role": "Driver", "message": "essaye", "annotation": {"form": "imperativeSentence", "tone": "positiveTone", "content": "notRelatedToProgramming_Other", "nature": "noFeedback"}}, {"messageID": 18, "role": "Navigator", "message": "attend", "annotation": {"form": "positiveSentence", "tone": "positiveTone", "content": "notRelatedToProgramming_Other", "nature": "noFeedback"}}, {"messageID": 19, "role": "Driver", "message": "je crois que c\'est bon", "annotation": {"form": "positiveSentence", "tone": "positiveTone", "content": "relatedToProgramming_relatedToTask", "nature": "correctResponse"}}, {"messageID": 20, "role": "Navigator", "message": "attend", "annotation": {"form": "positiveSentence", "tone": "positiveTone", "content": "notRelatedToProgramming_Other", "nature": "noFeedback"}}, {"messageID": 21, "role": "Navigator", "message": "attend", "annotation": {"form": "positiveSentence", "tone": "positiveTone", "content": "notRelatedToProgramming_Other", "nature": "noFeedback"}}]}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 4,\n  "conversation": [\n    {\n      "messageID": 22,\n      "role": "Driver",\n      "message": "Bonjour",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 23,\n      "role": "Navigator",\n      "message": "Bonjour",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 24,\n      "role": "Driver",\n      "message": "tu pense si je fais un for in in range avec un for j in range dedans ça peut marcher?",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "askingForHelp"\n      }\n    },\n    {\n      "messageID": 25,\n      "role": "Navigator",\n      "message": "oui ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "correctResponse"\n      }\n    },\n    {\n      "messageID": 26,\n      "role": "Driver",\n      "message": "tu veux editer?",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp"\n      }\n    },\n    {\n      "messageID": 27,\n      "role": "Navigator",\n      "message": "comme tu veux",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 28,\n      "role": "Driver",\n      "message": "je teste si ça marche pas on echange",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 29,\n      "role": "Navigator",\n      "message": "vsy ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 30,\n      "role": "Navigator",\n      "message": "en vrai c\'est pas mieux de faire un \\"if len(a) != len(b)\\"",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "taskKnowledge"\n      }\n    },\n    {\n      "messageID": 31,\n      "role": "Driver",\n      "message": "tu veux teste?",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp"\n      }\n    },\n    {\n      "messageID": 32,\n      "role": "Driver",\n      "message": "demande l\'édition",\n      "annotation": {\n        "form": "imperativeSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp"\n      }\n    },\n    {\n      "messageID": 33,\n      "role": "Navigator",\n      "message": "vsy je teste le code",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback"\n      }\n    },\n    {\n      "messageID": 34,\n      "role": "Navigator",\n      "message": "quand je teste le code il me disent y\'a des erreurs de type",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "negativeTone",\n        "content": "relatedToProgramming_notRelatedToTask",\n        "nature": "errors"\n      }\n    },\n     ...

# %%
out_df = convert_to_dataframe(labeled_data, [LABEL_COLUMN_1,LABEL_COLUMN_2,LABEL_COLUMN_3,LABEL_COLUMN_4])

out_df.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 out_df = convert_to_dataframe(labeled_data, [LABEL_COLUMN_1,LABEL_COLUMN_2,LABEL_COLUMN_3,LABEL_COLUMN_4])
#       3 out_df.head()
#
# Cell In[99], line 61, in convert_to_dataframe(list_of_json, label_columns)
#      48     # For every utterance in the conversation
#      49     for message in json_entry['conversation']:
#      50         # Create an entry (row) to use then in the dataframe
#      51         flattened_data.append({
#      52             'seance_ID' : seance_id,
#      53             'groupe_ID': groupe_id,
#      54             'messageID': message['messageID'],
#      55             'role': message['role'],
#      56             'message': message['message'],
#      57             label_columns[0] : message['annotation']['form'],    #ajouter ici les autres attributs
#      58             label_columns[1] : message['annotation']['tone'],
#      59             label_columns[2] : message['annotation']['content'],
#      60             label_columns[3] : message['annotation']['nature'],
# ---> 61             label_columns[4] : message['annotation']['form2']
#      62         })
#      64 # Convert the entries in a dataframe
#      65 out_df = pd.DataFrame(flattened_data)
#
# IndexError: list index out of range

# %%
out_df.to_csv("annotation_mistral_conv_0_to_5.csv")

# %% [markdown]
# ## Classification avec vouvoiement dans le prompt

# %%
client = Mistral(api_key=api_key)
prompt_system, prompt_user, prompt_agent = read_prompts(PROMPT_FOLDER_MISTRAL_VOUVOIEMENT)
labeled_data = classify_conversation_mistral(client,
                                    prompt_system,
                                    prompt_user,
                                    prompt_agent,
                                    conversations_dict[:5])
# Out:
# Classifying...: 100%|██████████| 5/5 [00:47<00:00,  9.53s/it]

# %%
out_df = convert_to_dataframe(labeled_data, [LABEL_COLUMN_1,LABEL_COLUMN_2,LABEL_COLUMN_3,LABEL_COLUMN_4])

out_df.head()
# Out:
#    seance_ID  groupe_ID       role  messageID  utterance_num  \
# 0          1          0  Navigator          0              0
# 1          1          0  Navigator          1              0
# 2          1          1     Driver          2              0
# 3          1          1     Driver          3              0
# 4          1          1  Navigator          4              0
#
#                     message             forme           ton  \
# 0               Tu es qui ?          question  positiveTone
# 1  On se met 5 partout ok ?  positiveSentence  positiveTone
# 2                       Opé  positiveSentence  positiveTone
# 3                  Opé lmkt  positiveSentence  positiveTone
# 4         A PAR SA LE COUZ   positiveSentence  positiveTone
#
#                          content         nature
# 0  notRelatedToProgramming_Other  askingForHelp
# 1  notRelatedToProgramming_Other     noFeedback
# 2  notRelatedToProgramming_Other     noFeedback
# 3  notRelatedToProgramming_Other     noFeedback
# 4  notRelatedToProgramming_Other     noFeedback

# %%
out_df.to_csv("annotation_mistral_vouvoiement_conv_0_to_5.csv")

# %% [markdown]
# ## Form v2

# %%
client = Mistral(api_key=api_key)
prompt_system, prompt_user, prompt_agent = read_prompts(PROMPT_FOLDER_MISTRAL_FORMV2)
labeled_data = classify_conversation_mistral(client,
                                    prompt_system,
                                    prompt_user,
                                    prompt_agent,
                                    conversations_dict[:5])
# Out:
# Classifying...:   0%|          | 0/5 [00:00<?, ?it/s]
# Classifying...: 100%|██████████| 5/5 [00:25<00:00,  5.13s/it]

# %%
labeled_data
# Out:
# ['{\n  "seance_ID": 1,\n  "groupe_ID": 0,\n  "conversation": [\n    {\n      "messageID": 0,\n      "role": "Navigator",\n      "message": "Tu es qui ,",\n      "annotation": {\n        "form": "question",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "question"\n      }\n    },\n    {\n      "messageID": 1,\n      "role": "Navigator",\n      "message": "On se met 5 partout ok ?",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    }\n  ]\n}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 1,\n  "conversation": [\n    {\n      "messageID": 2,\n      "role": "Driver",\n      "message": "Opé",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 3,\n      "role": "Driver",\n      "message": "Opé lmkt",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 4,\n      "role": "Navigator",\n      "message": "A PAR SA LE COUZ ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "negativeTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 5,\n      "role": "Navigator",\n      "message": "Opé ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 6,\n      "role": "Navigator",\n      "message": "Ou lé jolie ? ",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 7,\n      "role": "Navigator",\n      "message": "A ou ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 8,\n      "role": "Navigator",\n      "message": "Commencé ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 9,\n      "role": "Navigator",\n      "message": "Comment nous fé la ",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 10,\n      "role": "Navigator",\n      "message": "c\'est kwé faut fait ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 11,\n      "role": "Navigator",\n      "message": "Lève ton main un coup la ",\n      "annotation": {\n        "form": "imperativeSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 12,\n      "role": "Navigator",\n      "message": "aide a moins un coup la ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    }\n  ]\n}',
#  '{"seance_ID": 1, "groupe_ID": 2, "conversation": [{"messageID": 13, "role": "Driver", "message": "roro", "annotation": {"form": "neutral", "tone": "positiveTone", "content": "notRelatedToProgramming_Other", "nature": "noFeedback", "form2": "neutral"}}, {"messageID": 14, "role": "Driver", "message": "Qui est là", "annotation": {"form": "question", "tone": "positiveTone", "content": "notRelatedToProgramming_Other", "nature": "askingForHelp", "form2": "question"}}]}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 3,\n  "conversation": [\n    {\n      "messageID": 15,\n      "role": "Driver",\n      "message": "je ne sais pas comment voir le résultat ",\n      "annotation": {\n        "form": "negativeSentence",\n        "tone": "neutral",\n        "content": "relatedToProgramming_notRelatedToTask",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 16,\n      "role": "Navigator",\n      "message": "faut mettre print(coincide)",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "correctResponse",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 17,\n      "role": "Driver",\n      "message": "essaye",\n      "annotation": {\n        "form": "imperativeSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 18,\n      "role": "Navigator",\n      "message": "attend",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 19,\n      "role": "Driver",\n      "message": "je crois que c\'est bon",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 20,\n      "role": "Navigator",\n      "message": "attend",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 21,\n      "role": "Navigator",\n      "message": "attend",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    }\n  ]\n}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 4,\n  "conversation": [\n    {\n      "messageID": 22,\n      "role": "Driver",\n      "message": "Bonjour",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 23,\n      "role": "Navigator",\n      "message": "Bonjour",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 24,\n      "role": "Driver",\n      "message": "tu pense si je fais un for in in range avec un for j in range dedans ça peut marcher? ",\n      "annotation": {\n        "form": "question",\n        "tone": "neutral",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "askingForHelp",\n        "form2": "question"\n      }\n    },\n    {\n      "messageID": 25,\n      "role": "Navigator",\n      "message": "oui ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 26,\n      "role": "Driver",\n      "message": "tu veux editer?",\n      "annotation": {\n        "form": "question",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "question"\n      }\n    },\n    {\n      "messageID": 27,\n      "role": "Navigator",\n      "message": "comme tu veux",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 28,\n      "role": "Driver",\n      "message": "je teste si ça marche pas on echange",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 29,\n      "role": "Navigator",\n      "message": "vsy ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 30,\n      "role": "Navigator",\n      "message": "en vrai c\'est pas mieux de faire un \\"if len(a) != len(b)\\"",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "correctResponse",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 31,\n      "role": "Driver",\n      "message": "tu veux teste?",\n      "annotation": {\n        "form": "question",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "question"\n      }\n    },\n    {\n      "messageID": 32,\n      "role": "Driver",\n      "message": "demande l\'édition",\n      "annotation": {\n        "form": "imperativeSentence",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "imperativeSentence"\n      }\n    },\n    {\n      "messageID": 33,\n      "role": "Navigator",\n      "message": "vsy je teste le code",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n   ...

# %%
out_df = convert_to_dataframe(labeled_data, [LABEL_COLUMN_1,LABEL_COLUMN_2,LABEL_COLUMN_3,LABEL_COLUMN_4,LABEL_COLUMN_5])

out_df.head()
# Out:
#    seance_ID  groupe_ID                               file_ID       role  \
# 0          1          0  023a3090-7b0a-48c4-93f0-c200d9afce41  Navigator
# 1          1          0  023a3090-7b0a-48c4-93f0-c200d9afce41  Navigator
# 2          1          1  0435458c-dc49-4094-b970-1db125fc235c     Driver
# 3          1          1  0435458c-dc49-4094-b970-1db125fc235c     Driver
# 4          1          1  0435458c-dc49-4094-b970-1db125fc235c  Navigator
#
#    messageID  utterance_num                   message             forme  \
# 0          0              0               Tu es qui ,          question
# 1          1              0  On se met 5 partout ok ?  positiveSentence
# 2          2              0                       Opé  positiveSentence
# 3          3              0                  Opé lmkt  positiveSentence
# 4          4              0         A PAR SA LE COUZ   positiveSentence
#
#             ton                        content         nature    formv2
# 0       neutral  notRelatedToProgramming_Other  askingForHelp  question
# 1  positiveTone  notRelatedToProgramming_Other     noFeedback   neutral
# 2  positiveTone  notRelatedToProgramming_Other     noFeedback   neutral
# 3  positiveTone  notRelatedToProgramming_Other     noFeedback   neutral
# 4  negativeTone  notRelatedToProgramming_Other     noFeedback   neutral

# %%
out_df.to_csv("form2.csv")

# %% [markdown]
# ## Classification complète

# %%
client = Mistral(api_key=api_key)
prompt_system, prompt_user, prompt_agent = read_prompts(PROMPT_FOLDER_MISTRAL_FORMV2)
labeled_data = classify_conversation_mistral(client,
                                    prompt_system,
                                    prompt_user,
                                    prompt_agent,
                                    conversations_dict)
# Out:
# Classifying...:   0%|          | 0/102 [00:00<?, ?it/s]
# Classifying...: 100%|██████████| 102/102 [25:07<00:00, 14.78s/it]

# %%
labeled_data
# Out:
# ['{\n  "seance_ID": 1,\n  "groupe_ID": 0,\n  "conversation": [\n    {\n      "messageID": 0,\n      "role": "Navigator",\n      "message": "Tu es qui ,",\n      "annotation": {\n        "form": "question",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "question"\n      }\n    },\n    {\n      "messageID": 1,\n      "role": "Navigator",\n      "message": "On se met 5 partout ok ?",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "imperativeSentence"\n      }\n    }\n  ]\n}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 1,\n  "conversation": [\n    {\n      "messageID": 2,\n      "role": "Driver",\n      "message": "Opé",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 3,\n      "role": "Driver",\n      "message": "Opé lmkt",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 4,\n      "role": "Navigator",\n      "message": "A PAR SA LE COUZ ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "negativeTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 5,\n      "role": "Navigator",\n      "message": "Opé ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 6,\n      "role": "Navigator",\n      "message": "Ou lé jolie ? ",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 7,\n      "role": "Navigator",\n      "message": "A ou ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 8,\n      "role": "Navigator",\n      "message": "Commencé ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 9,\n      "role": "Navigator",\n      "message": "Comment nous fé la ",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 10,\n      "role": "Navigator",\n      "message": "c\'est kwé faut fait ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 11,\n      "role": "Navigator",\n      "message": "Lève ton main un coup la ",\n      "annotation": {\n        "form": "imperativeSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 12,\n      "role": "Navigator",\n      "message": "aide a moins un coup la ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    }\n  ]\n}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 2,\n  "conversation": [\n    {\n      "messageID": 13,\n      "role": "Driver",\n      "message": "roro",\n      "annotation": {\n        "form": "neutral",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 14,\n      "role": "Driver",\n      "message": "Qui est là",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "question"\n      }\n    }\n  ]\n}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 3,\n  "conversation": [\n    {\n      "messageID": 15,\n      "role": "Driver",\n      "message": "je ne sais pas comment voir le résultat ",\n      "annotation": {\n        "form": "negativeSentence",\n        "tone": "neutral",\n        "content": "relatedToProgramming_notRelatedToTask",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 16,\n      "role": "Navigator",\n      "message": "faut mettre print(coincide)",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "taskKnowledge",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 17,\n      "role": "Driver",\n      "message": "essaye",\n      "annotation": {\n        "form": "imperativeSentence",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 18,\n      "role": "Navigator",\n      "message": "attend",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 19,\n      "role": "Driver",\n      "message": "je crois que c\'est bon",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 20,\n      "role": "Navigator",\n      "message": "attend",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 21,\n      "role": "Navigator",\n      "message": "attend",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    }\n  ]\n}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 4,\n  "conversation": [\n    {\n      "messageID": 22,\n      "role": "Driver",\n      "message": "Bonjour",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 23,\n      "role": "Navigator",\n      "message": "Bonjour",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 24,\n      "role": "Driver",\n      "message": "tu pense si je fais un for in in range avec un for j in range dedans ça peut marcher? ",\n      "annotation": {\n        "form": "question",\n        "tone": "neutral",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "askingForHelp",\n        "form2": "question"\n      }\n    },\n    {\n      "messageID": 25,\n      "role": "Navigator",\n      "message": "oui ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 26,\n      "role": "Driver",\n      "message": "tu veux editer?",\n      "annotation": {\n        "form": "question",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "question"\n      }\n    },\n    {\n      "messageID": 27,\n      "role": "Navigator",\n      "message": "comme tu veux",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 28,\n      "role": "Driver",\n      "message": "je teste si ça marche pas on echange",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 29,\n      "role": "Navigator",\n      "message": "vsy ",\n      "annotation": {\n        "form": "neutral",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 30,\n      "role": "Navigator",\n      "message": "en vrai c\'est pas mieux de faire un \\"if len(a) != len(b)\\"",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "neutral",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "correctResponse",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 31,\n      "role": "Driver",\n      "message": "tu veux teste?",\n      "annotation": {\n        "form": "question",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "question"\n      }\n    },\n    {\n      "messageID": 32,\n      "role": "Driver",\n      "message": "demande l\'édition",\n      "annotation": {\n        "form": "imperativeSentence",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "imperativeSentence"\n      }\n    },\n    {\n      "messageID": 33,\n      "role": "Navigator",\n      "message": "vsy je teste le code",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 34,\n   ...
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 5,\n  "conversation": [\n    {\n      "messageID": 47,\n      "role": "Driver",\n      "message": "Il y a quelqu\'un",\n      "annotation": {\n        "form": "negativeSentence",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 48,\n      "role": "Navigator",\n      "message": "oui",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    }\n  ]\n}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 7,\n  "conversation": [\n    {\n      "messageID": 49,\n      "role": "Driver",\n      "message": "Yo!",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 50,\n      "role": "Navigator",\n      "message": "OUI",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 51,\n      "role": "Navigator",\n      "message": ",????",\n      "annotation": {\n        "form": "neutral",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 52,\n      "role": "Driver",\n      "message": "Oui",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 53,\n      "role": "Navigator",\n      "message": "C\'est bon pour toi",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "motivationnalFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 54,\n      "role": "Driver",\n      "message": "C\'est bon",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 55,\n      "role": "Driver",\n      "message": "Est ce que faut vérifié si les listes sont de la même longueur ?",\n      "annotation": {\n        "form": "question",\n        "tone": "neutral",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 56,\n      "role": "Navigator",\n      "message": "def coincide(tableau1, tableau2):     # On s\'assure que les deux tableaux ont la même longueur     if len(tableau1) != len(tableau2):         return []      # On crée un tableau vide pour stocker les indices où les éléments sont identiques     result = []          # On parcourt les deux tableaux et on compare les éléments     for i in range(len(tableau1)):         if tableau1[i] == tableau2[i]:             result.append(i)      return result  # Exemples d\'utilisation : print(coincide([78, 23, 12, 12, 54, 32], [67, 23, 44, 12, 54, 32]))  # [1, 3, 4, 5] print(coincide(["\n\n\n    }\n  ]\n}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 9,\n  "conversation": [\n    {\n      "messageID": 77,\n      "role": "Driver",\n      "message": "salut",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 78,\n      "role": "Navigator",\n      "message": "salut ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 79,\n      "role": "Navigator",\n      "message": "tu sais coder ou pas du tout ? ",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 80,\n      "role": "Driver",\n      "message": "pas forcément, j\'ai juste la base des bases",\n      "annotation": {\n        "form": "negativeSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "responseValidity",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 81,\n      "role": "Navigator",\n      "message": "okay ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 82,\n      "role": "Navigator",\n      "message": "et la ta compris un peu le contexte ? ",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 83,\n      "role": "Driver",\n      "message": "je sais qu\'il faut implémenter le tableau pour l\'utiliser dans la fonction coincide",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "taskKnowledge",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 84,\n      "role": "Navigator",\n      "message": "masi tkt si tu sais pas faire je vais faire ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "motivationnalFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 85,\n      "role": "Driver",\n      "message": "maintenant je vois ce qui est demandé",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "responseValidity",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 86,\n      "role": "Navigator",\n      "message": "ben je te laisse modifier si tu veux parce que je suis un peu perdu la ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 87,\n      "role": "Navigator",\n      "message": "c\'est bon j\'ai réussi ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "correctResponse",\n        "form2": "neutral"\n      }\n    }\n  ]\n}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 10,\n  "conversation": [\n    {\n      "messageID": 88,\n      "role": "Driver",\n      "message": "salut",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    }\n  ]\n}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 11,\n  "conversation": [\n    {\n      "messageID": 89,\n      "role": "Navigator",\n      "message": "yo ",\n      "annotation": {\n        "form": "neutral",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 90,\n      "role": "Navigator",\n      "message": "yo ",\n      "annotation": {\n        "form": "neutral",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    }\n  ]\n}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 12,\n  "conversation": [\n    {\n      "messageID": 91,\n      "role": "Driver",\n      "message": "Hello !!!",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    }\n  ]\n}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 14,\n  "conversation": [\n    {\n      "messageID": 92,\n      "role": "Navigator",\n      "message": "Test",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 93,\n      "role": "Navigator",\n      "message": "Chef ta la notif ?",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 94,\n      "role": "Driver",\n      "message": "sisi",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 95,\n      "role": "Navigator",\n      "message": "Ok Nice",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "motivationnalFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 96,\n      "role": "Navigator",\n      "message": "Chef ??",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 97,\n      "role": "Driver",\n      "message": "??",\n      "annotation": {\n        "form": "neutral",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 98,\n      "role": "Navigator",\n      "message": "Ta eu une deco en dirait",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "motivationnalFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 99,\n      "role": "Driver",\n      "message": "comment ca",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 100,\n      "role": "Navigator",\n      "message": "Je sais ça écris",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 101,\n      "role": "Navigator",\n      "message": "Ça",\n      "annotation": {\n        "form": "neutral",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 102,\n      "role": "Navigator",\n      "message": "C t",\n      "annotation": {\n        "form": "neutral",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 103,\n      "role": "Driver",\n      "message": "non meme pas hein ",\n      "annotation": {\n        "form": "negativeSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 104,\n      "role": "Navigator",\n      "message": "hmm Ça doit être ça ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n         ...
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 15,\n  "conversation": [\n    {\n      "messageID": 109,\n      "role": "Driver",\n      "message": "ya quelqu\'un ?",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 110,\n      "role": "Navigator",\n      "message": "oui je suis la !",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 111,\n      "role": "Navigator",\n      "message": "ça va ?",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 112,\n      "role": "Driver",\n      "message": "ouais tranquille",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 113,\n      "role": "Navigator",\n      "message": "sache que pour t\'aider a codé ça va être compliqué",\n      "annotation": {\n        "form": "negativeSentence",\n        "tone": "negativeTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "motivationnalFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 114,\n      "role": "Driver",\n      "message": "comment sa :(",\n      "annotation": {\n        "form": "question",\n        "tone": "negativeTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 115,\n      "role": "Navigator",\n      "message": "je comprend rien ",\n      "annotation": {\n        "form": "negativeSentence",\n        "tone": "negativeTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 116,\n      "role": "Driver",\n      "message": "ah merde ",\n      "annotation": {\n        "form": "negativeSentence",\n        "tone": "negativeTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 117,\n      "role": "Driver",\n      "message": "bah le code est bon ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 118,\n      "role": "Driver",\n      "message": "si tu veux que je t\'explique un truc",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 119,\n      "role": "Navigator",\n      "message": "ah t\'a fini ?",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 120,\n      "role": "Navigator",\n      "message": "wesh tu va grave vite",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "motivationnalFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 121,\n      "role": "Driver",\n ...
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 16,\n  "conversation": [\n    {\n      "messageID": 126,\n      "role": "Driver",\n      "message": "stp tu peux faire, parce que je sais pas trop programmer",\n      "annotation": {\n        "form": "negativeSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_relativeToRoles",\n        "nature": "askingForHelp",\n        "form2": "question"\n      }\n    },\n    {\n      "messageID": 127,\n      "role": "Navigator",\n      "message": "pareille mais essaye sur chat à tout moment ça passe ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "motivationnalFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 128,\n      "role": "Driver",\n      "message": "d\'accord",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 129,\n      "role": "Navigator",\n      "message": "t\'es vers dans la salle ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_relativeToRoles",\n        "nature": "taskKnowledge",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 130,\n      "role": "Navigator",\n      "message": "alors ça donne quoi ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "question"\n      }\n    },\n    {\n      "messageID": 131,\n      "role": "Driver",\n      "message": "tout devant ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 132,\n      "role": "Navigator",\n      "message": "alors ça donne quoi ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "question"\n      }\n    },\n    {\n      "messageID": 133,\n      "role": "Driver",\n      "message": "tout devant ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 134,\n      "role": "Driver",\n      "message": "j\'essaye encore",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 135,\n      "role": "Navigator",\n      "message": "d\'acccord vas y essaye de faire de ton mieux ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "motivationnalFeedback",\n        "form2": "neutral"\n      }\n    }\n  ]\n}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 18,\n  "conversation": [\n    {\n      "messageID": 136,\n      "role": "Driver",\n      "message": "SLT SLT",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_relativeToRoles",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 137,\n      "role": "Driver",\n      "message": "tg",\n      "annotation": {\n        "form": "neutral",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 138,\n      "role": "Driver",\n      "message": "deso ",\n      "annotation": {\n        "form": "neutral",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 139,\n      "role": "Driver",\n      "message": "c\'est pas moi",\n      "annotation": {\n        "form": "negativeSentence",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 140,\n      "role": "Driver",\n      "message": "#help",\n      "annotation": {\n        "form": "neutral",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 141,\n      "role": "Driver",\n      "message": "#help",\n      "annotation": {\n        "form": "neutral",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    }\n  ]\n}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 19,\n  "conversation": [\n    {\n      "messageID": 142,\n      "role": "Navigator",\n      "message": "coucou",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 143,\n      "role": "Driver",\n      "message": "BONJOUR",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 144,\n      "role": "Driver",\n      "message": "BONJOUR",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    }\n  ]\n}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 20,\n  "conversation": [\n    {\n      "messageID": 145,\n      "role": "Navigator",\n      "message": "salut",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    }\n  ]\n}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 21,\n  "conversation": [\n    {\n      "messageID": 146,\n      "role": "Driver",\n      "message": "salut",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 147,\n      "role": "Navigator",\n      "message": "yo ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 148,\n      "role": "Driver",\n      "message": "ça va",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 149,\n      "role": "Driver",\n      "message": "ça va",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 150,\n      "role": "Driver",\n      "message": "ça va",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    }\n  ]\n}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 22,\n  "conversation": [\n    {\n      "messageID": 151,\n      "role": "Driver",\n      "message": "wshhh",\n      "annotation": {\n        "form": "neutral",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 152,\n      "role": "Navigator",\n      "message": "slt",\n      "annotation": {\n        "form": "neutral",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 153,\n      "role": "Driver",\n      "message": "ca va ?",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "question"\n      }\n    },\n    {\n      "messageID": 154,\n      "role": "Navigator",\n      "message": "oui et toi?",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "question"\n      }\n    },\n    {\n      "messageID": 155,\n      "role": "Driver",\n      "message": "trkl leve la main la xD ",\n      "annotation": {\n        "form": "neutral",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 156,\n      "role": "Navigator",\n      "message": "pourquoi faire",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "question"\n      }\n    },\n    {\n      "messageID": 157,\n      "role": "Driver",\n      "message": "voir tes qui le s",\n      "annotation": {\n        "form": "neutral",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 158,\n      "role": "Driver",\n      "message": "nan",\n      "annotation": {\n        "form": "neutral",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 159,\n      "role": "Navigator",\n      "message": "t\'as une idéee",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "question"\n      }\n    },\n    {\n      "messageID": 160,\n      "role": "Navigator",\n      "message": "j\'ai plus d\'idée",\n      "annotation": {\n        "form": "neutral",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    }\n  ]\n}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 25,\n  "conversation": [\n    {\n      "messageID": 161,\n      "role": "Navigator",\n      "message": "Utilise append pour ajouter un élément dans une liste",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "taskKnowledge",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 162,\n      "role": "Navigator",\n      "message": "Utilise append pour ajouter un élément dans une liste",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "taskKnowledge",\n        "form2": "neutral"\n      }\n    }\n  ]\n}',
#  '{\n  "seance_ID": 1,\n  "groupe_ID": 27,\n  "conversation": [\n    {\n      "messageID": 163,\n      "role": "Navigator",\n      "message": "Je suis nulle je m\'excuse d\'avance pour mon incompétence",\n      "annotation": {\n        "form": "negativeSentence",\n        "tone": "negativeTone",\n        "content": "notRelatedToProgramming_relativeToRoles",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 164,\n      "role": "Driver",\n      "message": "ce n\'est pas grave on vas essayer pour y arriver  ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "motivationnalFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 165,\n      "role": "Navigator",\n      "message": "commence",\n      "annotation": {\n        "form": "imperativeSentence",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 166,\n      "role": "Driver",\n      "message": "mais par quoi ?",\n      "annotation": {\n        "form": "question",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 167,\n      "role": "Driver",\n      "message": "ah je vois ok",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "responseValidity",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 168,\n      "role": "Driver",\n      "message": "att une seconde tu es une fille ?",\n      "annotation": {\n        "form": "question",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 169,\n      "role": "Navigator",\n      "message": "oui ?",\n      "annotation": {\n        "form": "question",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 170,\n      "role": "Driver",\n      "message": "ah d\'accord",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "responseValidity",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 171,\n      "role": "Navigator",\n      "message": "j\'ai fais 2ans de NSI au cas me sous estime pas trop",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "taskKnowledge",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 172,\n      "role": "Driver",\n      "message": "bon vas y aller progressivement pour l\'exo",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "motivationnalFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 173,\n      "role": "Navigator",\n      "message": "au cas où*",\n      "annotation": {\n        "form": "neutral",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 174,\n      "role": "Driver",\n      "message": "d\'accord ne t\'inquite pas je suis du même cas ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "mot ...
# ...
#  '{\n  "seance_ID": 2,\n  "groupe_ID": 78,\n  "conversation": [\n    {\n      "messageID": 1634,\n      "role": "Driver",\n      "message": "Salut",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1635,\n      "role": "Navigator",\n      "message": "salut",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1636,\n      "role": "Driver",\n      "message": "cv",\n      "annotation": {\n        "form": "neutral",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1637,\n      "role": "Navigator",\n      "message": "oui",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1638,\n      "role": "Navigator",\n      "message": "et toi ?",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1639,\n      "role": "Driver",\n      "message": "cv cv",\n      "annotation": {\n        "form": "neutral",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1640,\n      "role": "Navigator",\n      "message": "cool",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1641,\n      "role": "Driver",\n      "message": "tu sais coder ?",\n      "annotation": {\n        "form": "question",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_relativeToRoles",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1642,\n      "role": "Navigator",\n      "message": "un peu",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1643,\n      "role": "Driver",\n      "message": "vas-y je te laisse faire",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1644,\n      "role": "Driver",\n      "message": "je promet pas de le completer au complet mais ca peux peut-être ce faire",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1645,\n      "role": "Navigator",\n      "message": "azy fait ce que tu peux",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "motivationnalFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1646,\n      "role": "Driver",\n      "message": "ok",\n      "annotation": {\n        "form": " ...
#  '{\n  "seance_ID": 2,\n  "groupe_ID": 79,\n  "conversation": [\n    {\n      "messageID": 1704,\n      "role": "Navigator",\n      "message": "salut",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1705,\n      "role": "Driver",\n      "message": "salut",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1706,\n      "role": "Navigator",\n      "message": "tu as la main donc tu peux commencer et bonne chance ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "motivationnalFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1707,\n      "role": "Driver",\n      "message": "Pour le coup c\'est toi qui l\'as",\n      "annotation": {\n        "form": "negativeSentence",\n        "tone": "negativeTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1708,\n      "role": "Navigator",\n      "message": "ah ok ! j\'avais pas remarqué",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1709,\n      "role": "Driver",\n      "message": "tqt",\n      "annotation": {\n        "form": "neutral",\n        "tone": "neutral",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1710,\n      "role": "Driver",\n      "message": "à mon avis il faudrait les mettre dans un simple quote mais séparément chacun ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_notRelatedToTask",\n        "nature": "taskKnowledge",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1711,\n      "role": "Navigator",\n      "message": "je te laisse pour me montrer d\'accord ?",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1712,\n      "role": "Driver",\n      "message": "asy attend j\'essaie si sa fonctionne déjà en python",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "howToProceed",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1713,\n      "role": "Navigator",\n      "message": "Définir un dictionnaire pour associer les délimiteurs ouvrants et fermants par le variable paire ",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "taskKnowledge",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1714,\n      "role": "Navigator",\n      "message": "je l\'ai déjà commencé",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "taskKnowledge",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1715,\n      "role": "Driver",\n      "message": "?",\n      "annotation": {\n        "form": "neutra ...
#  '{\n  "seance_ID": 2,\n  "groupe_ID": 80,\n  "conversation": [\n    {\n      "messageID": 1748,\n      "role": "Navigator",\n      "message": "Fe bour aou",\n      "annotation": {\n        "form": "negativeSentence",\n        "tone": "negativeTone",\n        "content": "relatedToProgramming_notRelatedToTask",\n        "nature": "askingForHelp",\n        "form2": "question"\n      }\n    },\n    {\n      "messageID": 1749,\n      "role": "Driver",\n      "message": "ok",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    }\n  ]\n}',
#  '{\n  "seance_ID": 2,\n  "groupe_ID": 81,\n  "conversation": [\n    {\n      "messageID": 1750,\n      "role": "Navigator",\n      "message": "salut",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1751,\n      "role": "Driver",\n      "message": "Salut salut !",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1752,\n      "role": "Driver",\n      "message": "On commence par créer la variable valeur ?",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "taskKnowledge",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1753,\n      "role": "Navigator",\n      "message": "oui",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1754,\n      "role": "Navigator",\n      "message": "tu commence",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1755,\n      "role": "Driver",\n      "message": "C\'est bon comme ça ?",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1756,\n      "role": "Driver",\n      "message": "Par contre pour la fonction je ne sais pas trop par quoi commencer ?",\n      "annotation": {\n        "form": "negativeSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1757,\n      "role": "Driver",\n      "message": "As-tu une idée ?",\n      "annotation": {\n        "form": "question",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "askingForHelp",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1758,\n      "role": "Navigator",\n      "message": "oui",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1759,\n      "role": "Driver",\n      "message": "teste",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1760,\n      "role": "Navigator",\n      "message": "T\'as mis totol, return tatol",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "relatedToProgramming_relatedToTask",\n        "nature": "correctResponse",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messageID": 1761,\n      "role": "Driver",\n      "message": "c\'est bon",\n      "annotation": {\n        "form": "positiveSentence",\n        "tone": "positiveTone",\n        "content": "notRelatedToProgramming_Other",\n        "nature": "noFeedback",\n        "form2": "neutral"\n      }\n    },\n    {\n      "messag ...

# %%
out_df = convert_to_dataframe(labeled_data, [LABEL_COLUMN_1,LABEL_COLUMN_2,LABEL_COLUMN_3,LABEL_COLUMN_4,LABEL_COLUMN_5])

out_df.head()
# Out:
# 56 is missing a key : 'annotation'
# 184 is missing a key : 'form'
# 185 is missing a key : 'form'
# 186 is missing a key : 'form'
# 187 is missing a key : 'form'
# 188 is missing a key : 'form'
# 189 is missing a key : 'form'
# 190 is missing a key : 'form'
# 191 is missing a key : 'form'
# 192 is missing a key : 'form'
# 193 is missing a key : 'form'
# 194 is missing a key : 'form'
# 195 is missing a key : 'form'
# 196 is missing a key : 'form'
# 197 is missing a key : 'form'
# 198 is missing a key : 'form'
# 199 is missing a key : 'form'
# 200 is missing a key : 'form'
# 498 is missing a key : 'form'
# 1264 is missing a key : 'form'
# 1268 is missing a key : 'form'
# 1381 is missing a key : 'form'
# {
#   "seance_ID": 2,
#   "groupe_ID": 75,
#   "conversation": [
#     {
#       "messageID": 1540,
#       "role": "Driver",
#       "message": "c qui?",
#       "annotation": {
#         "form": "negativeSentence",
#         "tone": "positiveTone",
#         "content": "relatedToProgramming_notRelatedToTask",
#         "nature": "askingForHelp",
#         "form2": "question"
#       }
#     },
#     {
#       "messageID": 1541,
#       "role": "Navigator",
#       "message": "c mr le blanc",
#       "annotation": {
#         "form": "positiveSentence",
#         "tone": "positiveTone",
#         "content": "notRelatedToProgramming_Other",
#         "nature": "noFeedback",
#         "form2": "neutral"
#       }
#     },
#     {
#       "messageID": 1542,
#       "role": "Navigator",
#       "message": "le gars devant en voir 4eme ranger a gauche",
#       "annotation": {
#         "form": "positiveSentence",
#         "tone": "positiveTone",
#         "content": "notRelatedToProgramming_Other",
#         "nature": "noFeedback",
#         "form2": "neutral"
#       }
#     },
#     {
#       "messageID": 1543,
#       "role": "Driver",
#       "message": "tu sais comment faire?",
#       "annotation": {
#         "form": "question",
#         "tone": "positiveTone",
#         "content": "relatedToProgramming_notRelatedToTask",
#         "nature": "askingForHelp",
#         "form2": "question"
#       }
#     },
#     {
#       "messageID": 1544,
#       "role": "Navigator",
#       "message": "non",
#       "annotation": {
#         "form": "positiveSentence",
#         "tone": "positiveTone",
#         "content": "relatedToProgramming_notRelatedToTask",
#         "nature": "noFeedback",
#         "form2": "neutral"
#       }
#     },
#     {
#       "messageID": 1545,
#       "role": "Navigator",
#       "message": "mais chat gpt oui",
#       "annotation": {
#         "form": "positiveSentence",
#         "tone": "positiveTone",
#         "content": "notRelatedToProgramming_Other",
#         "nature": "noFeedback",
#         "form2": "neutral"
#       }
#     },
#     {
#       "messageID": 1546,
#       "role": "Driver",
#       "message": "vasy",
#       "annotation": {
#         "form": "positiveSentence",
#         "tone": "positiveTone",
#         "content": "notRelatedToProgramming_Other",
#         "nature": "noFeedback",
#         "form2": "neutral"
#       }
#     },
#     {
#       "messageID": 1547,
#       "role": "Navigator",
#       "message": "ez",
#       "annotation": {
#         "form": "positiveSentence",
#         "tone": "positiveTone",
#         "content": "notRelatedToProgramming_Other",
#         "nature": "noFeedback",
#         "form2": "neutral"
#       }
#     },
#     {
#       "messageID": 1548,
#       "role": "Driver",
#       "message": "teste le après",
#       "annotation": {
#         "form": "positiveSentence",
#         "tone": "positiveTone",
#         "content": "relatedToProgramming_relatedToTask",
#         "nature": "howToProceed",
#         "form2": "imperativeSentence"
#       }
#     },
#     {
#       "messageID": 1549,
#       "role": "Navigator",
#       "message": "sa ma l'aire correct tt sa",
#       "annotation": {
#         "form": "positiveSentence",
#         "tone": "positiveTone",
#         "content": "notRelatedToProgramming_Other",
#         "nature": "noFeedback",
#         "form2": "neutral"
#       }
#     },
#     {
#       "messageID": 1550,
#       "role": "Driver",
#       "message": "jvais l'essayé pour voir",
#       "annotation": {
#         "form": "positiveSentence",
#         "tone": "positiveTone",
#         "content": "relatedToProgramming_relatedToTask",
#         "nature": "askingForHelp",
#         "form2": "imperativeSentence"
#       }
#     },
#     {
#       "messageID": 1551,
#       "role": "Driver",
#       "message": "                                      #::SX&A##@@@M#Sr2HBHBMMMM#MBAB#BMHAHAhsh. HTTPAAAAAAAA.FLASHMOUNTAIN.COM        @@sH@@@@@@@@M&9H#@@@@@@#MM#@@@#@@#&H@M##B&#MX@@                                    @@SG@@@@@@@@@@@@@@@H&@#@@@@MB@@MBHMXGMG;@BBMH3@@X                                    @rr#@@@@@M#@@@@2@@2rh@HB##X.@HGAh@3r@i;@@GG9A@@@                                   ,@@@A2@@As##@@3@;@G@3,@B3hH#:M@hMis@,i@r @&hBi5h@@                                    Gr   @r r&#A;;s @AM@;;@aaa#&B@@&@ri@ @@ 2@H&B&XG@@                                   @H:; @# G,:r, ;.s@3XH2 ###BBMHG@@@@,@,,@@ 3A9H9XAH@@                                    @:@@@.:@.:5; :.;XM&2A @##BHMB#H##@9@& @@&:HA#HAGBH#@:                                    @rB@@r@3hShSS2, r9X9GrHAHM#@@@@#@@@3@,:H#G,@H&Xi2@B#@s                                    @,;5@#@MHr;;;;H,.@Gss32&9XrrrSS9@#@@s@@32GAr;MM@SrSX3,@@                                    M#.r9@@H;5;  &i&A@@@@XsS23X3XS5GAA@r@@Sax@G9;S@#.:&Xrh@                                    @s 9 #@  @@s,..MBr    :3A@@9isrShHA;s@ @:#M#r M@h,;2rs@r                                   @h ,:,H@@    ,  5@@G@rM@@@BrsissSBHB5S@.@;;@s9r @HG,iss@r                                  @#.   sAH@@@2@@X  @@A;;.;   ;rrrrsM@#G;@.5. @Isi 2S95i;,@s                                 :@r ..;2;;H#@      @S3i     ;rrsiSSHHHM,@;s:.@2r3r.ii;s:rHG                                 @#:;; .;.MA#@     @@23X .,:,ri2X229#AA#,@5:;,@G3A5ss#2G,;:@                                 Xis:   ;.is#@i    S;;XG@ .;;siS552ShAAM:@@S2rAs9Sr# @Sh:, ##                                 @9;:,:,3, ,9@@  . @@@@#@92i53X99XXSXXA2:@A S#&i;3#Hr@;M;,:;@;                                 @S5,. ;r:  .@@@,          :;5XS2Sii2XH2;H@ir2Mr:@rX3A5A,., @H                                 H5 ,;r; ..  rrH@; H@;@@@#@@rr3S25S233M;23@AsXX:&@H5X2Xs..  @@H                                  3,,5; :;,,.  :2@. &   r@#;:;rS5i5XXG#iS;@MB9rsSSSS5i9;;:: 9G@,                                  M;:h.;;;:, ..  @@. 5@@@#iriisi522hAAHri;@A@@i5ShAH3XS,:;;:::@S                                   h S:;.   :::,::sX:      ,::;riXAH9Gh;rXAGHAA55@G&X3S;;;;r;:@                                   @;:;5i  @Si;;r;:s&r    rX&HM@@@#A&3SrsXABA#HGAB&rG2r;irs3&&                                   32Xs .r22s5r;siS&3@@BHMAASHMHXSSiiirrsr&H2@@@##i::;s2X2r2M                               i@@#hHH@2 sr;rs;,3ASs.A@#93;,,,,,,,:::;;:;;;SS3iXX3ir;..:::rr.@5                          sX@#MhAhh5;9@@ rXr#:,BhA;r S@hSrirrrrrrrrsr:. ;2rrrrsSSissr:;Sr.:r;,                       ,i;:.::;rsB&2i @@ # 53:S;GX;.;s@sr;ssrrrrrr;   ihsr;;r;;;rhh2Xr .  &                      :,     .r;;s2X# @@ 3i@s ;:si2r@:@rir;;;;;;r2S   9Sr;:::;rrsis,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# 1585 is missing a key : 'form'
#    seance_ID  groupe_ID                               file_ID       role  \
# 0          1          0  023a3090-7b0a-48c4-93f0-c200d9afce41  Navigator
# 1          1          0  023a3090-7b0a-48c4-93f0-c200d9afce41  Navigator
# 2          1          1  0435458c-dc49-4094-b970-1db125fc235c     Driver
# 3          1          1  0435458c-dc49-4094-b970-1db125fc235c     Driver
# 4          1          1  0435458c-dc49-4094-b970-1db125fc235c  Navigator
#
#    messageID  utterance_num                   message             forme  \
# 0          0              0               Tu es qui ,          question
# 1          1              0  On se met 5 partout ok ?  positiveSentence
# 2          2              0                       Opé  positiveSentence
# 3          3              0                  Opé lmkt  positiveSentence
# 4          4              0         A PAR SA LE COUZ   positiveSentence
#
#             ton                        content         nature  \
# 0       neutral  notRelatedToProgramming_Other  askingForHelp
# 1  positiveTone  notRelatedToProgramming_Other     noFeedback
# 2  positiveTone  notRelatedToProgramming_Other     noFeedback
# 3  positiveTone  notRelatedToProgramming_Other     noFeedback
# 4  negativeTone  notRelatedToProgramming_Other     noFeedback
#
#                formv2
# 0            question
# 1  imperativeSentence
# 2             neutral
# 3             neutral
# 4             neutral

# %%
out_df.to_csv("complete.csv")
